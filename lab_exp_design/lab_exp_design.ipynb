# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Jake"
ca1_name = "Jessica"
ca2_name = "Mia"
ca3_name = ""

# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Haibo Che"
partner1_netid = "haiboc2"
partner1_inYourGroupLastWeek = "yes"

partner2_name = "Siyu WU"
partner2_netid = "siyuwu6"
partner2_inYourGroupLastWeek = "no"

partner3_name = ""
partner3_netid = ""
partner3_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(Do you like to go out or stay in on the weekends？)*

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa24.csv")
df
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle  AL1, AL2                                 Heads
# 1      Prof. Wade  AL1, AL2                                 Tails
# 2        Angelina       Y13                                 Tails
# 3        TA Tyler       Y07                                 Tails
# 4          Sneha        Y17                                 Tails
# ...           ...       ...                                   ...
# 1065     Man Geun       Y04                                 Heads
# 1066     CA Elise  Y11, Y33                                 Heads
# 1067      Chinmay       Y11                                 Heads
# 1068        Bowen       Y25                                 Heads
# 1069     kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                      Not First Year
# 4                  First Year at UIUC
# ...                               ...
# 1065                   Not First Year
# 1066                   Not First Year
# 1067               First Year at UIUC
# 1068               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                               Vanilla
# 2                                               Vanilla
# 3                                             Chocolate
# 4                                               Vanilla
# ...                                                 ...
# 1065                                            Vanilla
# 1066                                            Vanilla
# 1067                                          Chocolate
# 1068                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 1                             Night                                Odd
# 2                           Morning                               Even
# 3                             Night                               Even
# 4                             Night                               Even
# ...                             ...                                ...
# 1065                          Night                               Even
# 1066                          Night                               Even
# 1067                          Night                               Even
# 1068                          Night                                Odd
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 3                    No                          Winter
# 4                    No                          Summer
# ...                 ...                             ...
# 1065                 No                          Winter
# 1066                Yes                          Summer
# 1067                 No                          Summer
# 1068                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                          Yes  ...
# ...                        ...  ...
# 1065                        No  ...
# 1066                        No  ...
# 1067                        No  ...
# 1068                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 1                                                Sweden
# 2                                            Hong Kong
# 3                                                Canada
# 4                                                Canada
# ...                                                 ...
# 1065                                              Korea
# 1066                                            England
# 1067                                              India
# 1068                                              China
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 3                          Orange                              Terraria
# 4                           Green                 Reading or crocheting
# ...                           ...                                   ...
# 1065                         Blue                           Playstation
# 1066                         Pink                          With friends
# 1067                         Blue                                 Music
# 1068                       Purple                                 Films
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 1                                          Pop
# 2                                          r&b
# 3                                     Pop rock
# 4                                     Pop Rock
# ...                                        ...
# 1065                                       Pop
# 1066                                 Indie pop
# 1067                                       Rap
# 1068                                      Rocj
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 1                                                   Fox
# 2                                                 Tiger
# 3                                                   Bee
# 4                                               Penguin
# ...                                                 ...
# 1065                                                Dog
# 1066                                               Wolf
# 1067                                                Dog
# 1068                                              Puppy
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 1                                   Computer Science
# 2                             Aerospace engineering
# 3                               Chemical Engineering
# 4                                   Computer Science
# ...                                              ...
# 1065                                              CS
# 1066                                            Eecs
# 1067                                Computer Science
# 1068                                     Engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 3                            Billy Joel
# 4                       Imagine Dragons
# ...                                 ...
# 1065                                 IU
# 1066                       Taylor swift
# 1067                       Travis Scott
# 1068                         Kanye West
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 1                                   YouTube
# 2                                     Insta
# 3                                    Reddit
# 4                                 Instagram
# ...                                     ...
# 1065                              Instagram
# 1066                              Pinterest
# 1067                              Instagram
# 1068                                    ins
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 1                                              Factorio
# 2                                                   NaN
# 3                                              Terraria
# 4                                            Beat Saber
# ...                                                 ...
# 1065                                              NBA2k
# 1066                                           Pinochle
# 1067                                             Tennis
# 1068                                     Stardew Valley
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 1                                Acadia
# 2                       Southern France
# 3                          My apartment
# 4                                 Italy
# ...                                 ...
# 1065                             Cancun
# 1066                              Kenya
# 1067                             Monaco
# 1068                              Tokyo
# 1069                            iceland
#
# [1070 rows x 150 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'When flipping a coin, heads or tails?',
#  'Is this your first year at UIUC?',
#  'Is your favorite ice cream flavor chocolate or vanilla?',
#  'Do you like morning or night? ',
#  'Do you prefer even or odd numbers?',
#  'Do you have a pet?',
#  'Do you prefer summer or winter?',
#  'Are you a business major?',
#  'Do you prefer Movies or TV shows?',
#  'Do you prefer pizza or hamburgers?',
#  'Are you male or female?',
#  'Do you prefer the color Blue or Red?',
#  'Do you like Taylor Swifts music?',
#  'Do you prefer sweet or salty food?',
#  'Do you eat breakfast in the mornings?',
#  'Ice cream or cake? ',
#  'Are you an upperclassman or an underclassman?',
#  'As you walk in from the back, do you prefer to sit on the left or right side of lecture?',
#  'Is the day of the month of your birthday an odd or even number?',
#  'Do you speak a second language?',
#  'Do you prefer cats or dogs?',
#  'Are you a morning person or a night person?',
#  'Do you enjoy reading?',
#  'Do you prefer milk chocolate or dark chocolate?',
#  'Do you prefer Italian or Mexican food?',
#  'Do you prefer sugar cookies or chocolate chip cookies?',
#  'Can you speak a second language fluently?',
#  'Do you prefer Math or English?',
#  'Do you like apples or bananas?',
#  'Waffles or pancakes?',
#  'Do you prefer day or night?',
#  'Do you prefer lecture halls or small classes? ',
#  'Are you in-state or out of state?',
#  'Do you typically shower in the morning or at night?',
#  'Does money buy happiness?',
#  'Do you prefer to party or stay in?',
#  'McDonalds or Burger King?',
#  'Do you prefer sweet or savory food?',
#  'What month is your birthday?',
#  'Do you drink a cup of coffee every morning?',
#  'Do you drink coffee?',
#  'Do you use a Mac or Windows Laptop?',
#  'Do you prefer brownies or cookies?',
#  'Google Docs or Microsoft Word?',
#  'Do you like horror movies?',
#  'Do you have programming experience?',
#  'Do you like pizza or pasta?',
#  'Do you wear glasses?',
#  'Do you like your dorm?',
#  'Fall or spring season?',
#  'Do you prefer pink or blue?',
#  'Are you from the Chicagoland area?',
#  'Does your NetID end with an even or odd number?',
#  'Are you wearing something on your wrist currently?',
#  'Is it called Futbol or Soccer?',
#  'Do you use corrective lenses (contacts/glasses)?',
#  'Do you prefer Apple Music or Spotify?',
#  'Do you have exactly one sibling?',
#  'Are you taking any other computer science classes?',
#  'In the DISCOVERY lecture, do you sit in the front 50% or back 50%?',
#  'Do you sit on the left or right side in lecture?',
#  'Pick a random number 1-10. is the number you picked odd or even?',
#  'Are you from Chicago?',
#  'Pick a number: One or Two.',
#  'Do you prefer to study alone or in groups?',
#  'Do you prefer Apple or Google maps?',
#  'Do you prefer apple juice or orange juice?',
#  'Do you prefer basketball or football?',
#  'Do you prefer the beach or mountains?',
#  'Is your UIN an even number?',
#  'Were you born before or after 2006?',
#  "Would you sit behind the driver or the passenger seat when you're at the back seat in a car?",
#  'Did you come from a big or a small high school?',
#  "Are you shorter or taller than 5'7 (170cm)?",
#  'Do you prefer breakfast or dinner?',
#  'Do you prefer go to school by bus or by walking?',
#  'Did the chicken or the egg come first?',
#  'Do you prefer Coca Cola or Pepsi?',
#  'Do you prefer Coca-Cola or Sprite?',
#  'Do you prefer coffee or tea?',
#  'Dawn or Dusk?',
#  'Would you rather drown or burn to death?',
#  'Are you an extrovert or introvert?',
#  'Do you prefer gold or silver jewelry?',
#  'Do you prefer group projects or solo assignments?',
#  'Do you prefer a hot location vacation or a cold vacation location?',
#  'Do you prefer hotdogs or hamburgers?',
#  'Are you taking stat107 for your major or not?',
#  'Who is a better poet?',
#  "Do you prefer 'light mode' or 'dark mode' on your technological devices?",
#  'Do you have long hair or short hair?',
#  'Do you prefer morning or afternoon classes?',
#  'Do you prefer indoor or outdoor activities?',
#  'Do you prefer Pizza or Cheeseburgers?',
#  'Do you like Messi or Ronaldo?',
#  'Do you prefer running or walking?',
#  'What soccer team is better?',
#  'Do you prefer strawberries or blueberries?',
#  'Do you live in student housing (i.e. dorms) or private housing (i.e. apartments)?',
#  'Do you like the warm or cold weather better?',
#  'Would you rather your head be the size of a watermelon or an orange?',
#  'Do you prefer wings or burgers?',
#  'Do you prefer Playstation or Xbox?',
#  'Y or N?',
#  'Do you like the color yellow?',
#  'Do you like ranch?',
#  'Were you born in the United States?',
#  'Do you consider yourself an international student?',
#  'Have you ever been outside of United States?',
#  'Have you ever had COVID-19?',
#  'Do you like chocolate?',
#  'Do you like spicy food?',
#  'What\'s the color of "the dress"? (See it here: https://en.wikipedia.org/wiki/The_dress)',
#  'Are you taking 16 or more credit hours this semester?',
#  'Do you have siblings?',
#  'Did you play sports in high school? ',
#  'Does pineapple belong on pizza?',
#  'Is purple your favorite color? ',
#  'Do you like bananas?',
#  'Do you like Champaign?',
#  'Do you like rainy weather?',
#  'Does the First Letter of your last name Start with a Letter A-L Including L? ',
#  'Do you like Durian?',
#  'Pick between TRUE or FALSE.',
#  'Do you prefer watching basketball or football games?',
#  'Do you prefer caramel or sprinkle toppings on your ice cream?',
#  'Can you swim? ',
#  'Would you rather be to see the future or change the past?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10. ',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'What number do you consider as an unlucky number?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'What is your favorite color?',
#  'Favorite way to spend your free time?',
#  'What genre of music do you like the most?',
#  'If you were an animal, which would you be? / What is your spirit animal?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your binary question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column = " Are you an extrovert or introvert?"
analysis_column
# Out:
# ' Are you an extrovert or introvert?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 1053), "You have not loaded the correct Hello Dataset."
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time.
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[["Are you an extrovert or introvert?"]]
# Out:
#      Are you an extrovert or introvert?
# 0                             Extrovert
# 1                             Introvert
# 2                             Introvert
# 3                             Introvert
# 4                             Extrovert
# ...                                 ...
# 1065                          Introvert
# 1066                          Introvert
# 1067                          Introvert
# 1068                          Extrovert
# 1069                          Introvert
#
# [1070 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df["Are you an extrovert or introvert?"]=="Extrovert"]
df1
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle  AL1, AL2                                 Heads
# 4          Sneha        Y17                                 Tails
# 5            Gage       Y10                                 Heads
# 7           Jaden       Y34                                 Heads
# 8            Eman       Y11                                 Heads
# ...           ...       ...                                   ...
# 1053       CA Sri  Y18, Y34                                 Heads
# 1056     TA Deeya  Y19, Y29                                 Tails
# 1057     CA Bella       Y34                                 Heads
# 1058     Isabella       Y25                                 Heads
# 1068        Bowen       Y25                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 4                  First Year at UIUC
# 5                  First Year at UIUC
# 7                  First Year at UIUC
# 8                  First Year at UIUC
# ...                               ...
# 1053                   Not First Year
# 1056                   Not First Year
# 1057                   Not First Year
# 1058               First Year at UIUC
# 1068               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 4                                               Vanilla
# 5                                               Vanilla
# 7                                             Chocolate
# 8                                             Chocolate
# ...                                                 ...
# 1053                                            Vanilla
# 1056                                          Chocolate
# 1057                                          Chocolate
# 1058                                            Vanilla
# 1068                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 4                             Night                               Even
# 5                             Night                               Even
# 7                           Morning                               Even
# 8                           Morning                               Even
# ...                             ...                                ...
# 1053                          Night                               Even
# 1056                          Night                               Even
# 1057                        Morning                               Even
# 1058                          Night                                Odd
# 1068                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 4                    No                          Summer
# 5                   Yes                          Winter
# 7                    No                          Summer
# 8                    No                          Summer
# ...                 ...                             ...
# 1053                 No                          Winter
# 1056                Yes                          Winter
# 1057                Yes                          Summer
# 1058                Yes                          Summer
# 1068                 No                          Summer
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 4                          Yes  ...
# 5                           No  ...
# 7                           No  ...
# 8                           No  ...
# ...                        ...  ...
# 1053                        No  ...
# 1056                        No  ...
# 1057                        No  ...
# 1058                       Yes  ...
# 1068                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 4                                                Canada
# 5                                               Canada
# 7                                                 japan
# 8                                                   UAE
# ...                                                 ...
# 1053                                        Switzerland
# 1056                                        New Zealand
# 1057                                            sweeden
# 1058                                          Australia
# 1068                                              China
#
#      What is your favorite color?       Favorite way to spend your free time?  \
# 0                            pink                               water skiing!
# 4                           Green                       Reading or crocheting
# 5                           Green                         Fishing or Hunting
# 7                            blue                           talk with friends
# 8                             Red                      Hang out with friends
# ...                           ...                                         ...
# 1053                         Blue                                       Sleep
# 1056                          Red  Spending time with my friends doing crafts
# 1057                       purple                                     outside
# 1058                         Blue                             Watching shows.
# 1068                       Purple                                       Films
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 4                                     Pop Rock
# 5                                 Grunge Rock
# 7                                          pop
# 8                                          R&B
# ...                                        ...
# 1053                                 Indie Pop
# 1056                                      Kpop
# 1057                                       pop
# 1058                                       Pop
# 1068                                      Rocj
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 4                                               Penguin
# 5                                                 Bear
# 7                                                   dog
# 8                                               Unicorn
# ...                                                 ...
# 1053                                           Capybara
# 1056                                   I would be a cat
# 1057                                          butterfly
# 1058                                            Raccoon
# 1068                                              Puppy
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 4                                   Computer Science
# 5                                              Math
# 7                                                 CS
# 8                                            Physics
# ...                                              ...
# 1053                                             ECE
# 1056                                             ECE
# 1057                            chemical engineering
# 1058                            Chemical Engineering
# 1068                                     Engineering
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 4                       Imagine Dragons
# 5                            Jim Croce
# 7                                 keshi
# 8                                   SZA
# ...                                 ...
# 1053                        Don Toliver
# 1056                                SZA
# 1057                       taylor swift
# 1058                       Lana Del Rey
# 1068                         Kanye West
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 4                                 Instagram
# 5                                    Tiktok
# 7                                    wechat
# 8                                 Instagram
# ...                                     ...
# 1053                                 TikTok
# 1056                              Instagram
# 1057                              pinterest
# 1058                                 Tiktok
# 1068                                    ins
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 4                                            Beat Saber
# 5                                           Titanfall 2
# 7                                                   LOL
# 8                                                  Sims
# ...                                                 ...
# 1053                         We're Not Really Strangers
# 1056                                        Royal Match
# 1057                             pretty pretty princess
# 1058                                       21 questions
# 1068                                     Stardew Valley
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 4                                 Italy
# 5                 Denali National Park
# 7                                 china
# 8                               Greece
# ...                                 ...
# 1053                        New Zealand
# 1056                           Thailand
# 1057                             vienna
# 1058                            Iceland
# 1068                              Tokyo
#
# [512 rows x 150 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df["Are you an extrovert or introvert?"]=="Introvert"]
df2
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 1     Prof. Wade  AL1, AL2                                 Tails
# 2       Angelina       Y13                                 Tails
# 3       TA Tyler       Y07                                 Tails
# 6          Mark        Y04                                 Heads
# 10     Stephanie       Y36                                 Heads
# ...          ...       ...                                   ...
# 1064      Wesley       Y02                                 Tails
# 1065    Man Geun       Y04                                 Heads
# 1066    CA Elise  Y11, Y33                                 Heads
# 1067     Chinmay       Y11                                 Heads
# 1069    kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                      Not First Year
# 6                      Not First Year
# 10                 First Year at UIUC
# ...                               ...
# 1064                   Not First Year
# 1065                   Not First Year
# 1066                   Not First Year
# 1067               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                               Vanilla
# 2                                               Vanilla
# 3                                             Chocolate
# 6                                             Chocolate
# 10                                            Chocolate
# ...                                                 ...
# 1064                                            Vanilla
# 1065                                            Vanilla
# 1066                                            Vanilla
# 1067                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                             Night                                Odd
# 2                           Morning                               Even
# 3                             Night                               Even
# 6                           Morning                               Even
# 10                            Night                               Even
# ...                             ...                                ...
# 1064                          Night                               Even
# 1065                          Night                               Even
# 1066                          Night                               Even
# 1067                          Night                               Even
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 3                    No                          Winter
# 6                    No                          Winter
# 10                   No                          Summer
# ...                 ...                             ...
# 1064                 No                          Summer
# 1065                 No                          Winter
# 1066                Yes                          Summer
# 1067                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 6                           No  ...
# 10                          No  ...
# ...                        ...  ...
# 1064                        No  ...
# 1065                        No  ...
# 1066                        No  ...
# 1067                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 1                                                Sweden
# 2                                            Hong Kong
# 3                                                Canada
# 6                                                Sweden
# 10                                                Japan
# ...                                                 ...
# 1064                                              japan
# 1065                                              Korea
# 1066                                            England
# 1067                                              India
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 3                          Orange                              Terraria
# 6                           green                               reading
# 10                           pink              hanging out with friends
# ...                           ...                                   ...
# 1064                         blue                                 sleep
# 1065                         Blue                           Playstation
# 1066                         Pink                          With friends
# 1067                         Blue                                 Music
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 1                                          Pop
# 2                                          r&b
# 3                                     Pop rock
# 6                                          pop
# 10                                         r&b
# ...                                        ...
# 1064                                       pop
# 1065                                       Pop
# 1066                                 Indie pop
# 1067                                       Rap
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                   Fox
# 2                                                 Tiger
# 3                                                   Bee
# 6                                                 Zebra
# 10                                                  cat
# ...                                                 ...
# 1064                                         dog/ camel
# 1065                                                Dog
# 1066                                               Wolf
# 1067                                                Dog
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 1                                   Computer Science
# 2                             Aerospace engineering
# 3                               Chemical Engineering
# 6                               computer engineering
# 10                                  Computer Science
# ...                                              ...
# 1064                                         english
# 1065                                              CS
# 1066                                            Eecs
# 1067                                Computer Science
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 3                            Billy Joel
# 6                                   sza
# 10                                  SZA
# ...                                 ...
# 1064                         juice wrld
# 1065                                 IU
# 1066                       Taylor swift
# 1067                       Travis Scott
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 1                                   YouTube
# 2                                     Insta
# 3                                    Reddit
# 6                                 instagram
# 10                                   tiktok
# ...                                     ...
# 1064                                youtube
# 1065                              Instagram
# 1066                              Pinterest
# 1067                              Instagram
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1                                              Factorio
# 2                                                   NaN
# 3                                              Terraria
# 6                                              Fortnite
# 10                                          crossy road
# ...                                                 ...
# 1064                                        brawl stars
# 1065                                              NBA2k
# 1066                                           Pinochle
# 1067                                             Tennis
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 1                                Acadia
# 2                       Southern France
# 3                          My apartment
# 6                             australia
# 10                                Japan
# ...                                 ...
# 1064                              japan
# 1065                             Cancun
# 1066                              Kenya
# 1067                             Monaco
# 1069                            iceland
#
# [554 rows x 150 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# *(extrovert= 48%  introvert=52.0%)*

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# *(I am suprised cuz I used thought that extrovert person is more than introvert.)*

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# *(Yes)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# **Randomly** select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#          Name    Lab When flipping a coin, heads or tails?  \
# 19      Brady    Y16                                 Heads
# 857    Ailani    Y01                                 Heads
# 144      Kyle    Y25                                 Tails
# 1002   Krisha  Y idk                                 Tails
# 711   Frannie    Y05                                 Heads
# ...       ...    ...                                   ...
# 594     Isaac    Y06                                 Heads
# 529    Violet    Y29                                 Heads
# 97       Thea    Y15                                 Tails
# 470    Dillon    Y29                                 Heads
# 752     Abhay    Y31                                 Heads
#
#      Is this your first year at UIUC?  \
# 19                 First Year at UIUC
# 857                    Not First Year
# 144                First Year at UIUC
# 1002                   Not First Year
# 711                First Year at UIUC
# ...                               ...
# 594                First Year at UIUC
# 529                First Year at UIUC
# 97                     Not First Year
# 470                First Year at UIUC
# 752                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 19                                              Vanilla
# 857                                             Vanilla
# 144                                           Chocolate
# 1002                                          Chocolate
# 711                                           Chocolate
# ...                                                 ...
# 594                                           Chocolate
# 529                                             Vanilla
# 97                                            Chocolate
# 470                                             Vanilla
# 752                                           Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 19                          Morning                                Odd
# 857                           Night                                Odd
# 144                           Night                               Even
# 1002                          Night                               Even
# 711                         Morning                               Even
# ...                             ...                                ...
# 594                           Night                               Even
# 529                           Night                               Even
# 97                            Night                               Even
# 470                           Night                               Even
# 752                           Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 19                   No                          Summer
# 857                 Yes                          Winter
# 144                  No                          Winter
# 1002                Yes                          Summer
# 711                 Yes                          Summer
# ...                 ...                             ...
# 594                 Yes                          Winter
# 529                 Yes                          Summer
# 97                  Yes                          Winter
# 470                  No                          Winter
# 752                 Yes                          Summer
#
#      Are you a business major?  ...  \
# 19                         Yes  ...
# 857                         No  ...
# 144                         No  ...
# 1002                        No  ...
# 711                        Yes  ...
# ...                        ...  ...
# 594                        Yes  ...
# 529                        Yes  ...
# 97                          No  ...
# 470                         No  ...
# 752                         No  ...
#
#      Besides the US, what country would you like to live in?  \
# 19                                                Italy
# 857                                               japan
# 144                                         Switzerland
# 1002                                        philippines
# 711                                              France
# ...                                                 ...
# 594                                         South Korea
# 529                                              canada
# 97                                               norway
# 470                                           Singapore
# 752                                               India
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 19                           Blue                               Golfing
# 857                          pink                    talking to friends
# 144                         Green                                Gaming
# 1002                         pink                              work out
# 711                          Pink                Hang out with friends
# ...                           ...                                   ...
# 594                           Red                              Sleeping
# 529                          blue                         with friends
# 97                           pink                           watching tv
# 470                         Green        Scrolling through social media
# 752                          Blue                       Watching movies
#
#      What genre of music do you like the most?  \
# 19                                     Country
# 857                                      k-pop
# 144                                 Orchestral
# 1002                                      r &b
# 711                                   Country
# ...                                        ...
# 594                                      Chill
# 529                                    country
# 97                                         pop
# 470                                        Pop
# 752                                       Rock
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 19                                                 Lion
# 857                                                 cat
# 144                                            Nautilus
# 1002                                             turtle
# 711                                             Dolphin
# ...                                                 ...
# 594                                                 Fox
# 529                                                 cow
# 97                                              fat cat
# 470                                                Frog
# 752                                                orca
#
#      What do you think is the hardest major at UIUC?  \
# 19                                  Computer Science
# 857                             anything engineering
# 144                                          Physics
# 1002                                computer science
# 711                                      Engineering
# ...                                              ...
# 594                                      Mathematics
# 529                                     engineering
# 97                                           physics
# 470                                      Engineering
# 752                                          Physics
#
#      Who is your favorite music artist?  \
# 19                           Zach Bryan
# 857                             enhypen
# 144                           Will Wood
# 1002                                sza
# 711                       Taylor Swift
# ...                                 ...
# 594                              laufey
# 529                         zach bryan
# 97               florence + the machine
# 470                              Avicii
# 752                        Fall Out Boy
#
#      What's your favorite social media app?  \
# 19                                 Snapchat
# 857                                  tiktok
# 144                                 Discord
# 1002                                 tiktok
# 711                                Tik Tok
# ...                                     ...
# 594                              Instagram
# 529                               instagram
# 97                                  twitter
# 470                               Instagram
# 752                                   Qoura
#
#      What is your favorite game to play (either video game or IRL)?  \
# 19                                    Pickup Basketball
# 857                          dress to impress on roblox
# 144                                              ROBLOX
# 1002                                             Roblox
# 711                                                 Uno
# ...                                                 ...
# 594                                    Metal gear solid
# 529                                                 tag
# 97                                            wizard101
# 470                                    Ultimate Frisbee
# 752                                        Apex Legends
#
#             Where is your dream vacation spot?
# 19                                        Rome
# 857                                south korea
# 144                                      Japan
# 1002                                     Paris
# 711                                     Greece
# ...                                        ...
# 594                                        NaN
# 529                                     greece
# 97                                    New York
# 470   University of Illinois Urbana Champaign
# 752                                     Venice
#
# [535 rows x 150 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also randomly select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#           Name  Lab When flipping a coin, heads or tails?  \
# 196      Emily  Y15                                 Heads
# 528    Arthur   Y21                                 Tails
# 160      Aidan  Y02                                 Heads
# 653      Henry  Y02                                 Tails
# 832   Nicholas  Y19                                 Heads
# ...        ...  ...                                   ...
# 723      Alex   Y36                                 Heads
# 280   Victoria  Y09                                 Tails
# 404     Nathan  Y20                                 Tails
# 729     Sydney  Y24                                 Tails
# 1057  CA Bella  Y34                                 Heads
#
#      Is this your first year at UIUC?  \
# 196                First Year at UIUC
# 528                First Year at UIUC
# 160                    Not First Year
# 653                First Year at UIUC
# 832                    Not First Year
# ...                               ...
# 723                First Year at UIUC
# 280                First Year at UIUC
# 404                First Year at UIUC
# 729                First Year at UIUC
# 1057                   Not First Year
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 196                                           Chocolate
# 528                                             Vanilla
# 160                                             Vanilla
# 653                                             Vanilla
# 832                                             Vanilla
# ...                                                 ...
# 723                                             Vanilla
# 280                                             Vanilla
# 404                                             Vanilla
# 729                                             Vanilla
# 1057                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 196                           Night                               Even
# 528                           Night                               Even
# 160                           Night                               Even
# 653                         Morning                               Even
# 832                           Night                               Even
# ...                             ...                                ...
# 723                           Night                               Even
# 280                           Night                               Even
# 404                         Morning                               Even
# 729                         Morning                               Even
# 1057                        Morning                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 196                  No                          Winter
# 528                 Yes                          Summer
# 160                 Yes                          Winter
# 653                 Yes                          Winter
# 832                  No                          Winter
# ...                 ...                             ...
# 723                  No                          Summer
# 280                 Yes                          Summer
# 404                 Yes                          Summer
# 729                 Yes                          Summer
# 1057                Yes                          Summer
#
#      Are you a business major?  ...  \
# 196                         No  ...
# 528                         No  ...
# 160                         No  ...
# 653                         No  ...
# 832                         No  ...
# ...                        ...  ...
# 723                        Yes  ...
# 280                         No  ...
# 404                        Yes  ...
# 729                        Yes  ...
# 1057                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 196   China (Shanghai!!! Best place ever. I miss my ...
# 528                                         South Korea
# 160                                             ireland
# 653                                               Swiss
# 832                                              Greece
# ...                                                 ...
# 723                                               Korea
# 280                                         Switzerland
# 404                                               Italy
# 729                                               Italy
# 1057                                            sweeden
#
#      What is your favorite color?  \
# 196                 bluish violet
# 528                   Dark Purple
# 160                          blue
# 653                          blue
# 832                          Blue
# ...                           ...
# 723                          Blue
# 280                      Lavender
# 404                          Grey
# 729                          pink
# 1057                       purple
#
#                   Favorite way to spend your free time?  \
# 196                                                sing
# 528                            Hanging out with friends
# 160                                            sleeping
# 653                                             Nature
# 832                                               Sleep
# ...                                                 ...
# 723                                              Soccer
# 280   Explore area with friends if I have energy. Sl...
# 404                                     Watching Sports
# 729                            Hanging out with friends
# 1057                                            outside
#
#      What genre of music do you like the most?  \
# 196                                  Pop / R&B
# 528                                All generes
# 160                                    hip hop
# 653                                        pop
# 832                               hip-hop/ R&B
# ...                                        ...
# 723                                        Rap
# 280                      EDM, dupstep or house
# 404                           Alternative Rock
# 729                                    Country
# 1057                                       pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 196                                  red-crowned crane
# 528                                               Shark
# 160                                              monkey
# 653                                                 fox
# 832                                              A bird
# ...                                                 ...
# 723                                             cheetah
# 280                                               Shark
# 404                                            Tortoise
# 729                                               koala
# 1057                                          butterfly
#
#      What do you think is the hardest major at UIUC?  \
# 196                                               CS
# 528                                    Astro-Physics
# 160                                            aero
# 653                                             Math
# 832                            Eletrical Engineering
# ...                                              ...
# 723                                      Engineering
# 280                             Computer Engineering
# 404   Nuclear, Plasma, and Radiological Engineering
# 729                                      Engineering
# 1057                            chemical engineering
#
#      Who is your favorite music artist?  \
# 196                        Taylor Swift
# 528                          Bruno Mars
# 160                        lana del rey
# 653                      Taylor  Swift
# 832                         Kenny Mason
# ...                                 ...
# 723                                  Ye
# 280     I have phases. Right now, Mau P
# 404                          Billy Joel
# 729                          Zach Bryan
# 1057                       taylor swift
#
#      What's your favorite social media app?  \
# 196                                  wechat
# 528                               Instagram
# 160                               Instagram
# 653                                Telegram
# 832                               Instagram
# ...                                     ...
# 723                               instagram
# 280                               Instagram
# 404                                Snapchat
# 729                                 Tik tok
# 1057                              pinterest
#
#      What is your favorite game to play (either video game or IRL)?  \
# 196                                       killer sudoku
# 528                                                 NaN
# 160                                              soccer
# 653                                               GTA5
# 832                                              Skyrim
# ...                                                 ...
# 723                                                fifa
# 280                                          Suika Game
# 404                                 College Football 25
# 729                                         Connections
# 1057                             pretty pretty princess
#
#                      Where is your dream vacation spot?
# 196   Northern Europe / Antarctic (A place where I c...
# 528                                              Hawaii
# 160                                              Greece
# 653                                               swiss
# 832                                              Brazil
# ...                                                 ...
# 723                                              Hawaii
# 280                                             Vietnam
# 404                                Minnesota Lake Cabin
# 729                                             Bahamas
# 1057                                             vienna
#
# [535 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
# Empty DataFrame
# Columns: [Name, Lab, When flipping a coin, heads or tails?, Is this your first year at UIUC?, Is your favorite ice cream flavor chocolate or vanilla?, Do you like morning or night? , Do you prefer even or odd numbers?, Do you have a pet?, Do you prefer summer or winter?, Are you a business major?, Do you prefer Movies or TV shows?, Do you prefer pizza or hamburgers?, Are you male or female?, Do you prefer the color Blue or Red?, Do you like Taylor Swifts music?, Do you prefer sweet or salty food?, Do you eat breakfast in the mornings?, Ice cream or cake? , Are you an upperclassman or an underclassman?, As you walk in from the back, do you prefer to sit on the left or right side of lecture?, Is the day of the month of your birthday an odd or even number?, Do you speak a second language?, Do you prefer cats or dogs?, Are you a morning person or a night person?, Do you enjoy reading?, Do you prefer milk chocolate or dark chocolate?, Do you prefer Italian or Mexican food?, Do you prefer sugar cookies or chocolate chip cookies?, Can you speak a second language fluently?, Do you prefer Math or English?, Do you like apples or bananas?, Waffles or pancakes?, Do you prefer day or night?, Do you prefer lecture halls or small classes? , Are you in-state or out of state?, Do you typically shower in the morning or at night?, Does money buy happiness?, Do you prefer to party or stay in?, McDonalds or Burger King?, Do you prefer sweet or savory food?, What month is your birthday?, Do you drink a cup of coffee every morning?, Do you drink coffee?, Do you use a Mac or Windows Laptop?, Do you prefer brownies or cookies?, Google Docs or Microsoft Word?, Do you like horror movies?, Do you have programming experience?, Do you like pizza or pasta?, Do you wear glasses?, Do you like your dorm?, Fall or spring season?, Do you prefer pink or blue?, Are you from the Chicagoland area?, Does your NetID end with an even or odd number?, Are you wearing something on your wrist currently?, Is it called Futbol or Soccer?, Do you use corrective lenses (contacts/glasses)?, Do you prefer Apple Music or Spotify?, Do you have exactly one sibling?, Are you taking any other computer science classes?, In the DISCOVERY lecture, do you sit in the front 50% or back 50%?, Do you sit on the left or right side in lecture?, Pick a random number 1-10. is the number you picked odd or even?, Are you from Chicago?, Pick a number: One or Two., Do you prefer to study alone or in groups?, Do you prefer Apple or Google maps?, Do you prefer apple juice or orange juice?, Do you prefer basketball or football?, Do you prefer the beach or mountains?, Is your UIN an even number?, Were you born before or after 2006?, Would you sit behind the driver or the passenger seat when you're at the back seat in a car?, Did you come from a big or a small high school?, Are you shorter or taller than 5'7 (170cm)?, Do you prefer breakfast or dinner?, Do you prefer go to school by bus or by walking?, Did the chicken or the egg come first?, Do you prefer Coca Cola or Pepsi?, Do you prefer Coca-Cola or Sprite?, Do you prefer coffee or tea?, Dawn or Dusk?, Would you rather drown or burn to death?, Are you an extrovert or introvert?, Do you prefer gold or silver jewelry?, Do you prefer group projects or solo assignments?, Do you prefer a hot location vacation or a cold vacation location?, Do you prefer hotdogs or hamburgers?, Are you taking stat107 for your major or not?, Who is a better poet?, Do you prefer 'light mode' or 'dark mode' on your technological devices?, Do you have long hair or short hair?, Do you prefer morning or afternoon classes?, Do you prefer indoor or outdoor activities?, Do you prefer Pizza or Cheeseburgers?, Do you like Messi or Ronaldo?, Do you prefer running or walking?, What soccer team is better?, Do you prefer strawberries or blueberries?, ...]
# Index: []
#
# [0 rows x 150 columns]

# %% [markdown]
# **Q4: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# *(Random sampling can result in participant overlap between the treatment and control groups.)*

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[~df.index.isin(treatment.index)]
control
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 1     Prof. Wade  AL1, AL2                                 Tails
# 2       Angelina       Y13                                 Tails
# 3       TA Tyler       Y07                                 Tails
# 12        Amanda       Y30                                 Heads
# 15        Roqaya       Y03                                 Heads
# ...          ...       ...                                   ...
# 1059     CA Lara  Y19, Y20                                 Tails
# 1060    TA Jimmy       Y21                                 Tails
# 1061   TA Kunlun  Y12, Y25                                 Heads
# 1067     Chinmay       Y11                                 Heads
# 1069    kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                      Not First Year
# 12                     Not First Year
# 15                 First Year at UIUC
# ...                               ...
# 1059                   Not First Year
# 1060               First Year at UIUC
# 1061               First Year at UIUC
# 1067               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                               Vanilla
# 2                                               Vanilla
# 3                                             Chocolate
# 12                                              Vanilla
# 15                                            Chocolate
# ...                                                 ...
# 1059                                          Chocolate
# 1060                                          Chocolate
# 1061                                          Chocolate
# 1067                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                             Night                                Odd
# 2                           Morning                               Even
# 3                             Night                               Even
# 12                            Night                               Even
# 15                          Morning                               Even
# ...                             ...                                ...
# 1059                          Night                               Even
# 1060                          Night                               Even
# 1061                        Morning                               Even
# 1067                          Night                               Even
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 3                    No                          Winter
# 12                  Yes                          Summer
# 15                   No                          Summer
# ...                 ...                             ...
# 1059                 No                          Summer
# 1060                 No                          Summer
# 1061                Yes                          Summer
# 1067                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 12                          No  ...
# 15                          No  ...
# ...                        ...  ...
# 1059                        No  ...
# 1060                        No  ...
# 1061                        No  ...
# 1067                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 1                                                Sweden
# 2                                            Hong Kong
# 3                                                Canada
# 12                                                Italy
# 15                                                Qatar
# ...                                                 ...
# 1059                                             Canada
# 1060                                                 UK
# 1061                                              China
# 1067                                              India
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 3                          Orange                              Terraria
# 12                         Purple                              Sleeping
# 15                           pink                  hangout with friends
# ...                           ...                                   ...
# 1059                        beige                               reading
# 1060                        Black                        Watching shows
# 1061                         blue                                  game
# 1067                         Blue                                 Music
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 1                                          Pop
# 2                                          r&b
# 3                                     Pop rock
# 12                                 Alternative
# 15                                         pop
# ...                                        ...
# 1059                                Riot grrrl
# 1060                                       Pop
# 1061                                      jazz
# 1067                                       Rap
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                   Fox
# 2                                                 Tiger
# 3                                                   Bee
# 12                                                Bunny
# 15                                                sloth
# ...                                                 ...
# 1059                                        sea anemone
# 1060                                              Panda
# 1061                                               egal
# 1067                                                Dog
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 1                                   Computer Science
# 2                             Aerospace engineering
# 3                               Chemical Engineering
# 12                              Computer Engineering
# 15                                  computer science
# ...                                              ...
# 1059                                         Physics
# 1060                                         Physics
# 1061                                              cs
# 1067                                Computer Science
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 3                            Billy Joel
# 12                               Hozier
# 15                         Dominic fike
# ...                                 ...
# 1059                            Slant 6
# 1060                         Kanye West
# 1061                           Coldplay
# 1067                       Travis Scott
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 1                                   YouTube
# 2                                     Insta
# 3                                    Reddit
# 12                                  Twitter
# 15                                instagram
# ...                                     ...
# 1059                                 Reddit
# 1060                                Discord
# 1061                                 Wechat
# 1067                              Instagram
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1                                              Factorio
# 2                                                   NaN
# 3                                              Terraria
# 12                                       Stardew Valley
# 15                                             monopoly
# ...                                                 ...
# 1059                                           Oxenfree
# 1060                                              Poker
# 1061                                          overwatch
# 1067                                             Tennis
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 1                                Acadia
# 2                       Southern France
# 3                          My apartment
# 12                               Japan
# 15                             Maldives
# ...                                 ...
# 1059                              Japan
# 1060                              Japan
# 1061                                 CA
# 1067                             Monaco
# 1069                            iceland
#
# [535 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you?
# - If you did not fill out the "Hello Survey", then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead  *(those are the names we used in the `Name` column).*

# %%
# Use this cell to find yourself in either `treatment` or `control` groups:
ProfWade_in_treatment = treatment[treatment['Name'] == 'Prof. Wade']
ProfWade_in_treatment

# ...feel free to add extra "Code" cells here if needed.
# Out:
#          Name       Lab When flipping a coin, heads or tails?  \
# 1  Prof. Wade  AL1, AL2                                 Tails
#
#   Is this your first year at UIUC?  \
# 1                   Not First Year
#
#   Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                            Vanilla
#
#   Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                          Night                                Odd
#
#   Do you have a pet? Do you prefer summer or winter?  \
# 1                Yes                          Winter
#
#   Are you a business major?  ...  \
# 1                        No  ...
#
#   Besides the US, what country would you like to live in?  \
# 1                                             Sweden
#
#   What is your favorite color? Favorite way to spend your free time?  \
# 1                       Purple                           Programming
#
#   What genre of music do you like the most?  \
# 1                                       Pop
#
#   If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                Fox
#
#   What do you think is the hardest major at UIUC?  \
# 1                                Computer Science
#
#   Who is your favorite music artist? What's your favorite social media app?  \
# 1                       Taylor Swift                                YouTube
#
#   What is your favorite game to play (either video game or IRL)?  \
# 1                                           Factorio
#
#   Where is your dream vacation spot?
# 1                             Acadia
#
# [1 rows x 150 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q5: Which group where you in -- treatment or control?**

# %% [markdown]
# *(Prof.Wade is in treatment group)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=0.5, random_state=1)
df1_treatment
# Out:
#          Name    Lab When flipping a coin, heads or tails?  \
# 112    XINGYI    Y05                                 Heads
# 747      Kate    Y24                                 Heads
# 635     David    Y24                                 Heads
# 511   Cassidy    Y34                                 Heads
# 1048   Molina    Y09                                 Heads
# ...       ...    ...                                   ...
# 1002   Krisha  Y idk                                 Tails
# 339   Charlie    Y05                                 Heads
# 626    Braden    Y11                                 Heads
# 906     Kenan    Y21                                 Tails
# 933      Nick    Y35                                 Heads
#
#      Is this your first year at UIUC?  \
# 112                    Not First Year
# 747                First Year at UIUC
# 635                First Year at UIUC
# 511                First Year at UIUC
# 1048               First Year at UIUC
# ...                               ...
# 1002                   Not First Year
# 339                First Year at UIUC
# 626                First Year at UIUC
# 906                First Year at UIUC
# 933                    Not First Year
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 112                                             Vanilla
# 747                                             Vanilla
# 635                                             Vanilla
# 511                                           Chocolate
# 1048                                          Chocolate
# ...                                                 ...
# 1002                                          Chocolate
# 339                                             Vanilla
# 626                                             Vanilla
# 906                                             Vanilla
# 933                                             Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 112                           Night                               Even
# 747                           Night                               Even
# 635                         Morning                               Even
# 511                           Night                               Even
# 1048                          Night                               Even
# ...                             ...                                ...
# 1002                          Night                               Even
# 339                         Morning                               Even
# 626                           Night                               Even
# 906                           Night                               Even
# 933                           Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 112                 Yes                          Winter
# 747                 Yes                          Summer
# 635                  No                          Summer
# 511                 Yes                          Winter
# 1048                 No                          Summer
# ...                 ...                             ...
# 1002                Yes                          Summer
# 339                  No                          Summer
# 626                 Yes                          Summer
# 906                  No                          Winter
# 933                 Yes                          Winter
#
#      Are you a business major?  ...  \
# 112                         No  ...
# 747                        Yes  ...
# 635                        Yes  ...
# 511                        Yes  ...
# 1048                        No  ...
# ...                        ...  ...
# 1002                        No  ...
# 339                        Yes  ...
# 626                        Yes  ...
# 906                        Yes  ...
# 933                         No  ...
#
#      Besides the US, what country would you like to live in?  \
# 112                                               China
# 747                                                  UK
# 635                                              France
# 511                                             England
# 1048                                        Switzerland
# ...                                                 ...
# 1002                                        philippines
# 339                                              Canada
# 626                                          Australia
# 906                                              Canada
# 933                                               China
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 112                          Blue                                gaming
# 747                          pink                                 Sleep
# 635                         black                                Coding
# 511                          Blue              Hanging out with friends
# 1048                       Purple                               Singing
# ...                           ...                                   ...
# 1002                         pink                              work out
# 339                          Blue                          With Friends
# 626                         green                     Hang with friends
# 906                          Blue                       Be with friends
# 933                        Orange                           contemplate
#
#      What genre of music do you like the most?  \
# 112                                       Rock
# 747                                        Pop
# 635                           Soul and country
# 511                                  Indie Pop
# 1048                                       Pop
# ...                                        ...
# 1002                                      r &b
# 339                                       R&B
# 626                                     House
# 906                                       Rock
# 933                                      phonk
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 112                                                 Dog
# 747                                                 Owl
# 635                                                Lion
# 511                                               Panda
# 1048                                                Cat
# ...                                                 ...
# 1002                                             turtle
# 339                                                 Dog
# 626                                                 dog
# 906                                                 Bat
# 933                                                 Cat
#
#      What do you think is the hardest major at UIUC?  \
# 112                                               CS
# 747                                               CS
# 635                                               EE
# 511                                         Comp Sci
# 1048                                              CS
# ...                                              ...
# 1002                                computer science
# 339                                               CS
# 626                                               CS
# 906                                               CS
# 933                                     Physics + CS
#
#      Who is your favorite music artist?  \
# 112                         NO favorite
# 747                             Rihanna
# 635                         Tame impala
# 511                                 SZA
# 1048                           Jay Chou
# ...                                 ...
# 1002                                sza
# 339                          The Weeknd
# 626                           Fredagain
# 906               Red Hot Chili Peppers
# 933                           TheFatRat
#
#      What's your favorite social media app?  \
# 112                                Bilibili
# 747                                Snapchat
# 635                                 Message
# 511                               Instagram
# 1048                                    Ins
# ...                                     ...
# 1002                                 tiktok
# 339                                  TikTok
# 626                                snapchat
# 906                               Instagram
# 933                                  Wechat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 112                                  Honkai : Star Rail
# 747                                           Minecraft
# 635                                  I don't play games
# 511                                         Pickleball?
# 1048                                         Video game
# ...                                                 ...
# 1002                                             Roblox
# 339                                          Basketball
# 626                                          Basketball
# 906                                              Soccer
# 933                                         hearthstone
#
#      Where is your dream vacation spot?
# 112                                  LA
# 747                         New Zealand
# 635                               Korea
# 511                               Paris
# 1048                        Switzerland
# ...                                 ...
# 1002                              Paris
# 339                              Norway
# 626                               Aruba
# 906                            Istanbul
# 933                                Moon
#
# [256 rows x 150 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1.drop(df1_treatment.index)
df1_control
# Out:
#           Name  Lab When flipping a coin, heads or tails?  \
# 4       Sneha   Y17                                 Tails
# 5         Gage  Y10                                 Heads
# 7        Jaden  Y34                                 Heads
# 15      Roqaya  Y03                                 Heads
# 17      Albert  Y10                                 Heads
# ...        ...  ...                                   ...
# 1046     harry  Y99                                 Heads
# 1047      Sana  Y04                                 Heads
# 1050    Rohail  Y15                                 Tails
# 1051  Preetesh  Y16                                 Heads
# 1058  Isabella  Y25                                 Heads
#
#      Is this your first year at UIUC?  \
# 4                  First Year at UIUC
# 5                  First Year at UIUC
# 7                  First Year at UIUC
# 15                 First Year at UIUC
# 17                 First Year at UIUC
# ...                               ...
# 1046                   Not First Year
# 1047                   Not First Year
# 1050               First Year at UIUC
# 1051               First Year at UIUC
# 1058               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 4                                               Vanilla
# 5                                               Vanilla
# 7                                             Chocolate
# 15                                            Chocolate
# 17                                              Vanilla
# ...                                                 ...
# 1046                                          Chocolate
# 1047                                            Vanilla
# 1050                                            Vanilla
# 1051                                            Vanilla
# 1058                                            Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 4                             Night                               Even
# 5                             Night                               Even
# 7                           Morning                               Even
# 15                          Morning                               Even
# 17                            Night                                Odd
# ...                             ...                                ...
# 1046                        Morning                               Even
# 1047                          Night                                Odd
# 1050                          Night                               Even
# 1051                        Morning                                Odd
# 1058                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 4                    No                          Summer
# 5                   Yes                          Winter
# 7                    No                          Summer
# 15                   No                          Summer
# 17                   No                          Summer
# ...                 ...                             ...
# 1046                Yes                          Summer
# 1047                Yes                          Summer
# 1050                 No                          Summer
# 1051                 No                          Summer
# 1058                Yes                          Summer
#
#      Are you a business major?  ...  \
# 4                          Yes  ...
# 5                           No  ...
# 7                           No  ...
# 15                          No  ...
# 17                          No  ...
# ...                        ...  ...
# 1046                       Yes  ...
# 1047                        No  ...
# 1050                       Yes  ...
# 1051                        No  ...
# 1058                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 4                                                Canada
# 5                                               Canada
# 7                                                 japan
# 15                                                Qatar
# 17                                               Poland
# ...                                                 ...
# 1046                                              china
# 1047                                              Dubai
# 1050                                              Dubai
# 1051                                              Japan
# 1058                                          Australia
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 4                           Green                 Reading or crocheting
# 5                           Green                   Fishing or Hunting
# 7                            blue                     talk with friends
# 15                           pink                  hangout with friends
# 17                            Red                                Soccer
# ...                           ...                                   ...
# 1046                          red                                 games
# 1047                        White                       With my friends
# 1050                         Pink                                  Read
# 1051                          Red                               Workout
# 1058                         Blue                       Watching shows.
#
#      What genre of music do you like the most?  \
# 4                                     Pop Rock
# 5                                 Grunge Rock
# 7                                          pop
# 15                                         pop
# 17                                         Rap
# ...                                        ...
# 1046                                    hiphop
# 1047                                       Rap
# 1050                                       R&B
# 1051                                       Pop
# 1058                                       Pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 4                                               Penguin
# 5                                                 Bear
# 7                                                   dog
# 15                                                sloth
# 17                                                Tiger
# ...                                                 ...
# 1046                                               lion
# 1047                                             Monkey
# 1050                                             Monkey
# 1051                                                Cat
# 1058                                            Raccoon
#
#      What do you think is the hardest major at UIUC?  \
# 4                                   Computer Science
# 5                                              Math
# 7                                                 CS
# 15                                  computer science
# 17                              Chemical Engineering
# ...                                              ...
# 1046                                            chem
# 1047                          Mechanical Engineering
# 1050                                         CS+Math
# 1051                                              CS
# 1058                            Chemical Engineering
#
#      Who is your favorite music artist?  \
# 4                       Imagine Dragons
# 5                            Jim Croce
# 7                                 keshi
# 15                         Dominic fike
# 17                         Travis Scott
# ...                                 ...
# 1046                             taylor
# 1047                          21 Savage
# 1050                      Playboi Carti
# 1051                      Billie Ellish
# 1058                       Lana Del Rey
#
#      What's your favorite social media app?  \
# 4                                 Instagram
# 5                                    Tiktok
# 7                                    wechat
# 15                                instagram
# 17                                Instagram
# ...                                     ...
# 1046                                  music
# 1047                                Tik Tok
# 1050                              Instagram
# 1051                              Instagram
# 1058                                 Tiktok
#
#      What is your favorite game to play (either video game or IRL)?  \
# 4                                            Beat Saber
# 5                                           Titanfall 2
# 7                                                   LOL
# 15                                             monopoly
# 17                                               Soccer
# ...                                                 ...
# 1046                                                lol
# 1047                                        Ice Skating
# 1050                                           Fortnite
# 1051                                         Volleyball
# 1058                                       21 questions
#
#      Where is your dream vacation spot?
# 4                                 Italy
# 5                 Denali National Park
# 7                                 china
# 15                             Maldives
# 17                              Croatia
# ...                                 ...
# 1046                               home
# 1047                      Bali or Egypt
# 1050                   Santorini Greece
# 1051                              Italy
# 1058                            Iceland
#
# [256 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=0.5, random_state=1) 
df2_treatment
# Out:
#         Name  Lab When flipping a coin, heads or tails?  \
# 516   Carlee  Y01                                 Heads
# 924     Maya  Y34                                 Heads
# 116  Spencer  Y15                                 Heads
# 226  Addison  Y17                                 Heads
# 636    Chris  Y66                                 Heads
# ..       ...  ...                                   ...
# 93     Lukas  Y36                                 Heads
# 948   Preity  Y12                                 Heads
# 194  Michael  Y33                                 Heads
# 974    Ethan  Y27                                 Heads
# 582     Lucy  Y34                                 Heads
#
#     Is this your first year at UIUC?  \
# 516                   Not First Year
# 924               First Year at UIUC
# 116               First Year at UIUC
# 226               First Year at UIUC
# 636                   Not First Year
# ..                               ...
# 93                First Year at UIUC
# 948                   Not First Year
# 194                   Not First Year
# 974               First Year at UIUC
# 582               First Year at UIUC
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 516                                          Chocolate
# 924                                            Vanilla
# 116                                            Vanilla
# 226                                          Chocolate
# 636                                            Vanilla
# ..                                                 ...
# 93                                           Chocolate
# 948                                            Vanilla
# 194                                            Vanilla
# 974                                            Vanilla
# 582                                          Chocolate
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 516                        Morning                               Even
# 924                          Night                                Odd
# 116                        Morning                               Even
# 226                          Night                               Even
# 636                          Night                               Even
# ..                             ...                                ...
# 93                           Night                               Even
# 948                          Night                               Even
# 194                          Night                               Even
# 974                          Night                               Even
# 582                        Morning                               Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 516                 No                          Summer
# 924                Yes                          Summer
# 116                 No                          Summer
# 226                Yes                          Summer
# 636                Yes                          Winter
# ..                 ...                             ...
# 93                 Yes                          Summer
# 948                 No                          Winter
# 194                Yes                          Summer
# 974                Yes                          Summer
# 582                Yes                          Summer
#
#     Are you a business major?  ...  \
# 516                       Yes  ...
# 924                        No  ...
# 116                       Yes  ...
# 226                       Yes  ...
# 636                        No  ...
# ..                        ...  ...
# 93                        Yes  ...
# 948                        No  ...
# 194                        No  ...
# 974                       Yes  ...
# 582                       Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 516                                        New Zealand
# 924                                              Italy
# 116                                             Taiwan
# 226                                     United Kingdom
# 636                                        South Korea
# ..                                                 ...
# 93                                               Japan
# 948                                        Switzerland
# 194                                              China
# 974                                          Australia
# 582                                             canada
#
#     What is your favorite color? Favorite way to spend your free time?  \
# 516                         Blue                            Exercising
# 924                         Pink                                TikTok
# 116                       Orange                    Watching One Piece
# 226                        Black                               Golfing
# 636                       Yellow                               Rotting
# ..                           ...                                   ...
# 93                          blue                         playing games
# 948                        Black            Spending time with friends
# 194                       Orange                                Eating
# 974                         Blue              Hanging out with friends
# 582                        green                      watching netflix
#
#     What genre of music do you like the most?  \
# 516                                     Indie
# 924                                       Pop
# 116                                    Touhou
# 226                                       Pop
# 636                                       Pop
# ..                                        ...
# 93                                      indie
# 948                                       Pop
# 194                                       Pop
# 974                                   Country
# 582                                       pop
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 516                                      Mountain goat
# 924                                                Dog
# 116                                          Red Panda
# 226                                              Bunny
# 636                                               Bear
# ..                                                 ...
# 93                                                 cat
# 948                                                NaN
# 194                                                Dog
# 974                                                NaN
# 582                                              koala
#
#     What do you think is the hardest major at UIUC?  \
# 516                                Computer Science
# 924                                Computer Science
# 116                                        Comp Sci
# 226                                    Astrophysics
# 636                                         Physics
# ..                                              ...
# 93                               Law and philosophy
# 948                            Computer Engineering
# 194                          Electrical Engineering
# 974                                     Engineering
# 582                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 516                         Noah Kahan                                 Tiktok
# 924                    Phoebe Bridgers                                 TikTok
# 116                       Active NEETs                                YouTube
# 226                       Taylor Swift                                Tik tok
# 636                      Daniel Caesar                              Instagram
# ..                                 ...                                    ...
# 93                                 NaN                                  insta
# 948                       Selena Gomez                              Instagram
# 194                                M83                                Discord
# 974                          Jon Pardi                              Instagram
# 582                              drake                               snapchat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 516                                             Spoons
# 924                                           Leap Day
# 116                                             Roblox
# 226                                             Euchre
# 636                                      Yakuza series
# ..                                                 ...
# 93                                                 LOL
# 948                                             Tennis
# 194                                           Valorant
# 974                                           Baseball
# 582                                         mario kart
#
#     Where is your dream vacation spot?
# 516                       Switezerland
# 924                             Greece
# 116                            Bahamas
# 226                              Japan
# 636                            Sapporo
# ..                                 ...
# 93                               Balli
# 948                        Switzerland
# 194                          Singapore
# 974                          Australia
# 582                             greece
#
# [277 rows x 150 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2.drop(df2_treatment.index)
df2_control
# Out:
#            Name       Lab When flipping a coin, heads or tails?  \
# 3      TA Tyler       Y07                                 Tails
# 14       Smaya        Y30                                 Tails
# 16      Aaliyay       Y30                                 Heads
# 19        Brady       Y16                                 Heads
# 29        Jiali       Y30                                 Heads
# ...         ...       ...                                   ...
# 1060   TA Jimmy       Y21                                 Tails
# 1061  TA Kunlun  Y12, Y25                                 Heads
# 1063      Shlok       Y04                                 Heads
# 1065   Man Geun       Y04                                 Heads
# 1067    Chinmay       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 3                      Not First Year
# 14                 First Year at UIUC
# 16                 First Year at UIUC
# 19                 First Year at UIUC
# 29                 First Year at UIUC
# ...                               ...
# 1060               First Year at UIUC
# 1061               First Year at UIUC
# 1063               First Year at UIUC
# 1065                   Not First Year
# 1067               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 3                                             Chocolate
# 14                                            Chocolate
# 16                                              Vanilla
# 19                                              Vanilla
# 29                                              Vanilla
# ...                                                 ...
# 1060                                          Chocolate
# 1061                                          Chocolate
# 1063                                          Chocolate
# 1065                                            Vanilla
# 1067                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 3                             Night                               Even
# 14                          Morning                                Odd
# 16                            Night                               Even
# 19                          Morning                                Odd
# 29                            Night                                Odd
# ...                             ...                                ...
# 1060                          Night                               Even
# 1061                        Morning                               Even
# 1063                          Night                               Even
# 1065                          Night                               Even
# 1067                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 3                    No                          Winter
# 14                   No                          Winter
# 16                  Yes                          Summer
# 19                   No                          Summer
# 29                   No                          Summer
# ...                 ...                             ...
# 1060                 No                          Summer
# 1061                Yes                          Summer
# 1063                 No                          Summer
# 1065                 No                          Winter
# 1067                 No                          Summer
#
#      Are you a business major?  ...  \
# 3                           No  ...
# 14                          No  ...
# 16                          No  ...
# 19                         Yes  ...
# 29                         Yes  ...
# ...                        ...  ...
# 1060                        No  ...
# 1061                        No  ...
# 1063                        No  ...
# 1065                        No  ...
# 1067                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 3                                                Canada
# 14                                                Spain
# 16                                              Canada
# 19                                                Italy
# 29                                                Japan
# ...                                                 ...
# 1060                                                 UK
# 1061                                              China
# 1063                                             Monaco
# 1065                                              Korea
# 1067                                              India
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 3                          Orange                              Terraria
# 14                         purple                       Listen to music
# 16                           blue                              on phone
# 19                           Blue                               Golfing
# 29                         Purple                                 Sleep
# ...                           ...                                   ...
# 1060                        Black                        Watching shows
# 1061                         blue                                  game
# 1063                        Black                    Listening to music
# 1065                         Blue                           Playstation
# 1067                         Blue                                 Music
#
#      What genre of music do you like the most?  \
# 3                                     Pop rock
# 14                                       Indie
# 16                                         rnb
# 19                                     Country
# 29                                        Kpop
# ...                                        ...
# 1060                                       Pop
# 1061                                      jazz
# 1063                                   Hip Hop
# 1065                                       Pop
# 1067                                       Rap
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 3                                                   Bee
# 14                                               donkey
# 16                                                 bird
# 19                                                 Lion
# 29                                                  Cat
# ...                                                 ...
# 1060                                              Panda
# 1061                                               egal
# 1063                                                Dog
# 1065                                                Dog
# 1067                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 3                               Chemical Engineering
# 14                                               ECE
# 16                             aerospace engineering
# 19                                  Computer Science
# 29                                       Engineering
# ...                                              ...
# 1060                                         Physics
# 1061                                              cs
# 1063                            Computer Engineering
# 1065                                              CS
# 1067                                Computer Science
#
#      Who is your favorite music artist?  \
# 3                            Billy Joel
# 14                               Hozier
# 16                          Frank Ocean
# 19                           Zach Bryan
# 29                              Enhypen
# ...                                 ...
# 1060                         Kanye West
# 1061                           Coldplay
# 1063                         Kanye West
# 1065                                 IU
# 1067                       Travis Scott
#
#      What's your favorite social media app?  \
# 3                                    Reddit
# 14                                Instagram
# 16                                   tiktok
# 19                                 Snapchat
# 29                                   TikTok
# ...                                     ...
# 1060                                Discord
# 1061                                 Wechat
# 1063                              Instagram
# 1065                              Instagram
# 1067                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 3                                              Terraria
# 14                                             Celeste
# 16                                               sims 4
# 19                                    Pickup Basketball
# 29                                     Dress To Impress
# ...                                                 ...
# 1060                                              Poker
# 1061                                          overwatch
# 1063                                              Chess
# 1065                                              NBA2k
# 1067                                             Tennis
#
#      Where is your dream vacation spot?
# 3                          My apartment
# 14                                Paris
# 16                               eurpoe
# 19                                 Rome
# 29                          Switzerland
# ...                                 ...
# 1060                              Japan
# 1061                                 CA
# 1063                              Spain
# 1065                             Cancun
# 1067                             Monaco
#
# [277 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd.concat([df1_treatment, df2_treatment])
treatment
# Out:
#          Name  Lab When flipping a coin, heads or tails?  \
# 112    XINGYI  Y05                                 Heads
# 747      Kate  Y24                                 Heads
# 635     David  Y24                                 Heads
# 511   Cassidy  Y34                                 Heads
# 1048   Molina  Y09                                 Heads
# ...       ...  ...                                   ...
# 93      Lukas  Y36                                 Heads
# 948    Preity  Y12                                 Heads
# 194   Michael  Y33                                 Heads
# 974     Ethan  Y27                                 Heads
# 582      Lucy  Y34                                 Heads
#
#      Is this your first year at UIUC?  \
# 112                    Not First Year
# 747                First Year at UIUC
# 635                First Year at UIUC
# 511                First Year at UIUC
# 1048               First Year at UIUC
# ...                               ...
# 93                 First Year at UIUC
# 948                    Not First Year
# 194                    Not First Year
# 974                First Year at UIUC
# 582                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 112                                             Vanilla
# 747                                             Vanilla
# 635                                             Vanilla
# 511                                           Chocolate
# 1048                                          Chocolate
# ...                                                 ...
# 93                                            Chocolate
# 948                                             Vanilla
# 194                                             Vanilla
# 974                                             Vanilla
# 582                                           Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 112                           Night                               Even
# 747                           Night                               Even
# 635                         Morning                               Even
# 511                           Night                               Even
# 1048                          Night                               Even
# ...                             ...                                ...
# 93                            Night                               Even
# 948                           Night                               Even
# 194                           Night                               Even
# 974                           Night                               Even
# 582                         Morning                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 112                 Yes                          Winter
# 747                 Yes                          Summer
# 635                  No                          Summer
# 511                 Yes                          Winter
# 1048                 No                          Summer
# ...                 ...                             ...
# 93                  Yes                          Summer
# 948                  No                          Winter
# 194                 Yes                          Summer
# 974                 Yes                          Summer
# 582                 Yes                          Summer
#
#      Are you a business major?  ...  \
# 112                         No  ...
# 747                        Yes  ...
# 635                        Yes  ...
# 511                        Yes  ...
# 1048                        No  ...
# ...                        ...  ...
# 93                         Yes  ...
# 948                         No  ...
# 194                         No  ...
# 974                        Yes  ...
# 582                        Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 112                                               China
# 747                                                  UK
# 635                                              France
# 511                                             England
# 1048                                        Switzerland
# ...                                                 ...
# 93                                                Japan
# 948                                         Switzerland
# 194                                               China
# 974                                           Australia
# 582                                              canada
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 112                          Blue                                gaming
# 747                          pink                                 Sleep
# 635                         black                                Coding
# 511                          Blue              Hanging out with friends
# 1048                       Purple                               Singing
# ...                           ...                                   ...
# 93                           blue                         playing games
# 948                         Black            Spending time with friends
# 194                        Orange                                Eating
# 974                          Blue              Hanging out with friends
# 582                         green                      watching netflix
#
#      What genre of music do you like the most?  \
# 112                                       Rock
# 747                                        Pop
# 635                           Soul and country
# 511                                  Indie Pop
# 1048                                       Pop
# ...                                        ...
# 93                                       indie
# 948                                        Pop
# 194                                        Pop
# 974                                    Country
# 582                                        pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 112                                                 Dog
# 747                                                 Owl
# 635                                                Lion
# 511                                               Panda
# 1048                                                Cat
# ...                                                 ...
# 93                                                  cat
# 948                                                 NaN
# 194                                                 Dog
# 974                                                 NaN
# 582                                               koala
#
#      What do you think is the hardest major at UIUC?  \
# 112                                               CS
# 747                                               CS
# 635                                               EE
# 511                                         Comp Sci
# 1048                                              CS
# ...                                              ...
# 93                                Law and philosophy
# 948                             Computer Engineering
# 194                           Electrical Engineering
# 974                                      Engineering
# 582                                               CS
#
#      Who is your favorite music artist?  \
# 112                         NO favorite
# 747                             Rihanna
# 635                         Tame impala
# 511                                 SZA
# 1048                           Jay Chou
# ...                                 ...
# 93                                  NaN
# 948                        Selena Gomez
# 194                                 M83
# 974                           Jon Pardi
# 582                               drake
#
#      What's your favorite social media app?  \
# 112                                Bilibili
# 747                                Snapchat
# 635                                 Message
# 511                               Instagram
# 1048                                    Ins
# ...                                     ...
# 93                                    insta
# 948                               Instagram
# 194                                 Discord
# 974                               Instagram
# 582                                snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 112                                  Honkai : Star Rail
# 747                                           Minecraft
# 635                                  I don't play games
# 511                                         Pickleball?
# 1048                                         Video game
# ...                                                 ...
# 93                                                  LOL
# 948                                              Tennis
# 194                                            Valorant
# 974                                            Baseball
# 582                                          mario kart
#
#      Where is your dream vacation spot?
# 112                                  LA
# 747                         New Zealand
# 635                               Korea
# 511                               Paris
# 1048                        Switzerland
# ...                                 ...
# 93                                Balli
# 948                         Switzerland
# 194                           Singapore
# 974                           Australia
# 582                              greece
#
# [533 rows x 150 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control])
control
# Out:
#            Name       Lab When flipping a coin, heads or tails?  \
# 4        Sneha        Y17                                 Tails
# 5          Gage       Y10                                 Heads
# 7         Jaden       Y34                                 Heads
# 15       Roqaya       Y03                                 Heads
# 17       Albert       Y10                                 Heads
# ...         ...       ...                                   ...
# 1060   TA Jimmy       Y21                                 Tails
# 1061  TA Kunlun  Y12, Y25                                 Heads
# 1063      Shlok       Y04                                 Heads
# 1065   Man Geun       Y04                                 Heads
# 1067    Chinmay       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 4                  First Year at UIUC
# 5                  First Year at UIUC
# 7                  First Year at UIUC
# 15                 First Year at UIUC
# 17                 First Year at UIUC
# ...                               ...
# 1060               First Year at UIUC
# 1061               First Year at UIUC
# 1063               First Year at UIUC
# 1065                   Not First Year
# 1067               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 4                                               Vanilla
# 5                                               Vanilla
# 7                                             Chocolate
# 15                                            Chocolate
# 17                                              Vanilla
# ...                                                 ...
# 1060                                          Chocolate
# 1061                                          Chocolate
# 1063                                          Chocolate
# 1065                                            Vanilla
# 1067                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 4                             Night                               Even
# 5                             Night                               Even
# 7                           Morning                               Even
# 15                          Morning                               Even
# 17                            Night                                Odd
# ...                             ...                                ...
# 1060                          Night                               Even
# 1061                        Morning                               Even
# 1063                          Night                               Even
# 1065                          Night                               Even
# 1067                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 4                    No                          Summer
# 5                   Yes                          Winter
# 7                    No                          Summer
# 15                   No                          Summer
# 17                   No                          Summer
# ...                 ...                             ...
# 1060                 No                          Summer
# 1061                Yes                          Summer
# 1063                 No                          Summer
# 1065                 No                          Winter
# 1067                 No                          Summer
#
#      Are you a business major?  ...  \
# 4                          Yes  ...
# 5                           No  ...
# 7                           No  ...
# 15                          No  ...
# 17                          No  ...
# ...                        ...  ...
# 1060                        No  ...
# 1061                        No  ...
# 1063                        No  ...
# 1065                        No  ...
# 1067                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 4                                                Canada
# 5                                               Canada
# 7                                                 japan
# 15                                                Qatar
# 17                                               Poland
# ...                                                 ...
# 1060                                                 UK
# 1061                                              China
# 1063                                             Monaco
# 1065                                              Korea
# 1067                                              India
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 4                           Green                 Reading or crocheting
# 5                           Green                   Fishing or Hunting
# 7                            blue                     talk with friends
# 15                           pink                  hangout with friends
# 17                            Red                                Soccer
# ...                           ...                                   ...
# 1060                        Black                        Watching shows
# 1061                         blue                                  game
# 1063                        Black                    Listening to music
# 1065                         Blue                           Playstation
# 1067                         Blue                                 Music
#
#      What genre of music do you like the most?  \
# 4                                     Pop Rock
# 5                                 Grunge Rock
# 7                                          pop
# 15                                         pop
# 17                                         Rap
# ...                                        ...
# 1060                                       Pop
# 1061                                      jazz
# 1063                                   Hip Hop
# 1065                                       Pop
# 1067                                       Rap
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 4                                               Penguin
# 5                                                 Bear
# 7                                                   dog
# 15                                                sloth
# 17                                                Tiger
# ...                                                 ...
# 1060                                              Panda
# 1061                                               egal
# 1063                                                Dog
# 1065                                                Dog
# 1067                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 4                                   Computer Science
# 5                                              Math
# 7                                                 CS
# 15                                  computer science
# 17                              Chemical Engineering
# ...                                              ...
# 1060                                         Physics
# 1061                                              cs
# 1063                            Computer Engineering
# 1065                                              CS
# 1067                                Computer Science
#
#      Who is your favorite music artist?  \
# 4                       Imagine Dragons
# 5                            Jim Croce
# 7                                 keshi
# 15                         Dominic fike
# 17                         Travis Scott
# ...                                 ...
# 1060                         Kanye West
# 1061                           Coldplay
# 1063                         Kanye West
# 1065                                 IU
# 1067                       Travis Scott
#
#      What's your favorite social media app?  \
# 4                                 Instagram
# 5                                    Tiktok
# 7                                    wechat
# 15                                instagram
# 17                                Instagram
# ...                                     ...
# 1060                                Discord
# 1061                                 Wechat
# 1063                              Instagram
# 1065                              Instagram
# 1067                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 4                                            Beat Saber
# 5                                           Titanfall 2
# 7                                                   LOL
# 15                                             monopoly
# 17                                               Soccer
# ...                                                 ...
# 1060                                              Poker
# 1061                                          overwatch
# 1063                                              Chess
# 1065                                              NBA2k
# 1067                                             Tennis
#
#      Where is your dream vacation spot?
# 4                                 Italy
# 5                 Denali National Park
# 7                                 china
# 15                             Maldives
# 17                              Croatia
# ...                                 ...
# 1060                              Japan
# 1061                                 CA
# 1063                              Spain
# 1065                             Cancun
# 1067                             Monaco
#
# [533 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."
assert(
  (len(treatment) + len(control) == len(df1) + len(df2)) or 
  (len(treatment) + len(control) == len(df))
), f"Not everyone in the dataset (or everyone who responded to the question being blocked) is included in one of the two groups -- someone is missing! :(\nPeople in treatment group: {len(treatment)}\nPeople in control group: {len(control)}\nTotal in treatment+control group: {len(control) + len(treatment)}\n== vs ==\nTotal people in dataset: {len(df)}\nTotal people with data for blocking: {len(df1) + len(df2)}"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
