# %% [markdown]
# # Welcome to Lab: GPA 🎓
#
# In this lab, you'll explore the GPA dataset again to find out more about the courses at Illinois!
#
# Fun fact: the dataset you're using in this lab is the same dataset that Professor Wade uses to make the GPA visualizations! :)  Check this out here if you haven't seen it already: [https://waf.cs.illinois.edu/discovery/grade_disparity_between_sections_at_uiuc/](https://waf.cs.illinois.edu/discovery/grade_disparity_between_sections_at_uiuc/)
#
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab TA, your CAs, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Jake"
ca1_name = "Jessica"
ca2_name = "Mia"
ca3_name = ""


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!
#
# Question of the Day (QOTD) to Ask Your Group: "What's your favorite thing about fall?"
partner1_name = "Haibo Che"
partner1_netid = "habiboc2"
partner1_favfall = "tennis"

partner2_name = "Siyu WU"
partner2_netid = "suyuw6"
partner2_favfall = "tempurate"

partner3_name = ""
partner3_netid = ""
partner3_favfall= ""

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Exploring GPA

# %% [markdown]
# ## Load the GPA Dataset
#
# Before we begin exploring the GPA Dataset, we've got to load it in! The most recent version of the "GPA Dataset" (up to Winter 2024) is available here:
# ```
# https://waf.cs.illinois.edu/discovery/gpa.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`:

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/gpa.csv")

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(df) == 69112), "This is not the GPA dataset you're looking for."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.1: The "Average GPA" Column
# Each row in the GPA Dataset represents a **course section** at Illinois. For our exploratory data analysis, we are going to need an additional `Average GPA` column.
#
# To create this column, we need to compute the **weighted average GPA** for each course section by taking into account the **number of students** who received each letter grade.
#
# Add this new `Average GPA` column to our DataFrame `df` by finding the **products** of the **weight** associated with each **letter grade** and the number of said **letter grade** earned in each course section, **summing these products**, and then **dividing** by the **number of students** in the course section.
#
# Remember:
# - The **weight** of letter grades are as follows: $[A+ = 4.0, A = 4.0, A- = 3.67, \ldots  D- = 0.67, F = 0]$. <br> You can find a full scale at: https://registrar.illinois.edu/courses-grades/explanation-of-grades/
# - The `Students` column of our DataFrame contains the number of students in a course section
# - You've done this in your Mastery Platform homework before, now you're doing it for real :)

# %%
df['Average GPA'] = (df["A+"]*4+df["A"]*4+df["A-"]*3.67+df["B+"]*3.33+df["B"]*3+df["B-"]*2.67+df["C+"]*2.33+df["C"]*2+df["C-"]*1.67+df["D+"]*1.33+df["D"]*1+df["D-"]*0.67)/df["Students"]
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2024  Winter  2024-wi     ADV     150    Introduction to Advertising
# 1      2024  Winter  2024-wi    AFRO     100   Intro to African American St
# 2      2024  Winter  2024-wi    ASTR     330          Extraterrestrial Life
# 3      2024  Winter  2024-wi    ATMS     120   Severe and Hazardous Weather
# 4      2024  Winter  2024-wi    BADM     275          Operations Management
# ...     ...     ...      ...     ...     ...                            ...
# 69107  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 69108  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 69109  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 69110  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 69111  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
#       Sched Type  A+   A  A-  ...  C  C-  D+  D  D-  F  W  \
# 0            ONL  22  18   1  ...  0   0   0  0   0  0  0
# 1            ONL   5   8   6  ...  1   1   0  0   0  1  0
# 2            ONL   1  16   8  ...  0   2   0  1   0  0  0
# 3            ONL   3  16   3  ...  2   1   1  1   1  2  0
# 4            ONL   0  49  17  ...  3   0   0  0   0  0  0
# ...          ...  ..  ..  ..  ... ..  ..  .. ..  .. .. ..
# 69107        LEC   5  10   2  ...  1   3   0  0   0  2  1
# 69108        LEC   4  12   8  ...  0   0   0  0   0  0  0
# 69109        LEC   0   1   3  ...  1   1   0  2   0  1  0
# 69110        LCD   1   2   2  ...  3   2   0  0   1  1  0
# 69111        LEC   5   8   9  ...  4   0   0  1   0  2  0
#
#              Primary Instructor  Students  Average GPA
# 0                Hall, Steven R        42     3.968333
# 1          McMillion, Desiree Y        25     3.467600
# 2                Dunne, Bryan C        37     3.495946
# 3             Choate, Jessica J        46     3.108696
# 4                     Hu, Junqi        81     3.712346
# ...                         ...       ...          ...
# 69107        Stepanov, Alexei G        31     3.183226
# 69108              Unger, David        28     3.774643
# 69109         Morgan, William T        28     2.595714
# 69110  Ott-Monsivais, Stephanie        21     2.603333
# 69111          Keane, Richard D        39     3.205641
#
# [69112 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 1.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( len(df) == 69112  ), "You shouldn't be changing the length of `df` when computing Average GPA."
assert( "Average GPA" in df.columns), "Make sure your new column is named 'Average GPA'."
assert( math.isclose(df['Average GPA'].mean(), 3.3790213685614776)), "Your calculation of the Average GPA is incorrect."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.2: The "Hardest" and "Easiest" Courses?
# One way to judge a course's difficulty is to consider its **Average GPA**.
#
# Using the `Average GPA` column and the two cells below, find:
# - The **50** courses with the **lowest** `Average GPA`, storing in the DataFrame `df_hard`
# - The **50** courses with the **highest** `Average GPA`, storing the DataFrame `df_easy`

# %%
df_hard = df.sort_values(by="Average GPA").head(50)
df_hard
# Out:
#        Year    Term YearTerm Subject  Number                    Course Title  \
# 9053   2022  Spring  2022-sp      GS     199        College Academic Success
# 27054  2018    Fall  2018-fa     LER     120     Contemporary Labor Problems
# 11058  2021    Fall  2021-fa    CLCV     100  Vocab Building-GRK & LAT Roots
# 39524  2016  Spring  2016-sp     LER     100   Introduction to Labor Studies
# 47323  2014    Fall  2014-fa     LER     120     Contemporary Labor Problems
# 12160  2021    Fall  2021-fa     LER     100   Introduction to Labor Studies
# 49591  2014  Spring  2014-sp     LER     120     Contemporary Labor Problems
# 52380  2013    Fall  2013-fa    MATH       2            Introductory Algebra
# 49666  2014  Spring  2014-sp    MATH     220                        Calculus
# 24326  2019  Spring  2019-sp     LER     100   Introduction to Labor Studies
# 37252  2016    Fall  2016-fa     LER     120     Contemporary Labor Problems
# 47323        ONL   0  4   0  ...   4   1   0   1   0  15  1
# 12160        ONL   0  1   0  ...   3   0   2   0   1  11  0
# 49591        ONL   0  1   3  ...   3   0   0   0   2  11  0
# 52380        LCD   0  0   0  ...  10   5   3   3   2   5  3
# 49666        LBD   0  3   0  ...   5   0   2   1   0  11  1
# 24326        ONL   0  2   1  ...   0   0   0   2   1   9  0
# 37252        NaN   0  2   2  ...   0   1   2   1   2   8  2
# 37520        NaN   0  0   0  ...   3   4   1   2   0   6  1
# 47370        LCD   3  1   0  ...   1   1   1   0   2  11  1
# 47534        LAB   0  0   1  ...   1   3   5   1   1   5  0
# 34457        NaN   0  2   1  ...   3   2   0   1   0   9  0
# 28405        NaN   1  5   8  ...  10   9  11  23  10  26  7
# 37248        NaN   0  2   1  ...   3   2   0   1   1  10  0
# 10305        ONL   0  1   0  ...   2   2   2   1   3   5  0
# 37251        NaN   0  4   2  ...   2   1   0   1   4   8  0
# 62850        LCD   1  4   2  ...   5   0   9  11   2  18  0
# 37511        NaN   0  0   1  ...   1   3   3   4   1   4  2
# 62786        ONL   2  1   0  ...   1   2   0   0   1   9  2
# 1950         ONL   1  0   2  ...   1   1   0   1   0  11  1
# 49186        LCD   0  1   3  ...   1   2   1   0   0   8  1
# 42309        LCD   1  3   0  ...   3   1   1   1   1   8  0
# 27264        LAB   0  0   1  ...   4   1   0   1   1   7  0
# 37516        NaN   0  0   1  ...   3   1   1   1   3   6  0
# 15234        ONL   2  3   4  ...  10   4   7  10  13  13  1
# 61198        LEC   1  0   4  ...  23   3   6  23   9  11  0
# 47119        LEC   4  1   3  ...  13  10   9   8   2  14  4
# 54688        LCD   0  3   5  ...   9   6   6   3   6  26  4
# 25163        ONL   0  2   2  ...   4   3   3   3   9  10  6
# 60311        ONL   0  3   0  ...   2   3   0   3   0   7  0
# 22305        LAB   0  0   1  ...   3   1   1   1   2   6  1
# 34462        NaN   0  3   2  ...   3   0   0   1   0  12  2
# 39528        ONL   0  1   4  ...   2   0   0   1   1   9  0
# 37517        NaN   1  0   0  ...   3   4   1   1   3   3  0
# 10304        ONL   0  1   0  ...   3   2   2   1   2   5  0
# 37250        NaN   0  2   2  ...   1   3   0   0   0  11  2
# 46883        LCD   0  0   1  ...   3   4   2   1   0   8  0
# 49568        ONL   0  1   1  ...   1   1   2   1   3   6  0
# 13962         OD   2  1   0  ...   3   2   0   2   1   8  0
# 48264        DIS   0  0   1  ...   2   2   1   1   5   2  0
# 9359         ONL   0  1   3  ...   3   1   0   2   0   7  0
# 12262        LCD   1  1   2  ...   2   3   0   0   1   8  0
# 54903        DIS   0  0   0  ...   3   3   1   3   1   2  0
# 8769         LAB   2  1   0  ...   2   0   2   2   7   1  0
# 351           ST   0  2   0  ...   2   4   0   6   1   2  0
# 45587        LCD   0  0   0  ...   4   0   0   0   4   6  0
# 41744        LCD   0  1   0  ...   2   0   2   1   0   9  1
#
#               Primary Instructor  Students  Average GPA
# 9053               Walk, Aaron J        26     1.140385
# 27054                Taylor, Don        28     1.142857
# 11058      Augoustakis, Antonios        40     1.208750
# 3149   2023  Spring  2023-sp    BADM     324     Purchasing and Supply Mgmnt
# 21604  2019    Fall  2019-fa     FIN     447         Real Estate Development
# 7567   2022    Fall  2022-fa     SBC     512  Professional SBC Capstone Proj
# 5050   2023  Summer  2023-su     MUS     133     Introduction to World Music
# 33336  2017  Spring  2017-sp    BADM     566         Supply Chain Management
# 4578   2023  Spring  2023-sp    MUSC     484                    Concert Band
# 3265   2023  Spring  2023-sp     BUS     201               Business Dynamics
# 1367   2023    Fall  2023-fa     FIN     423         Entrepreneurial Finance
# 31892  2017    Fall  2017-fa      IB     199      Undergraduate Open Seminar
# 29017  2018  Spring  2018-sp    EPSY     490  Prep for Recruitment Counselor
# 11550  2021    Fall  2021-fa    EPOL     500              Proseminar in EPOL
# 16672  2020    Fall  2020-fa    EPSY     408    Learning & Hum Dev w/ EdTech
# 33037  2017  Spring  2017-sp    ACCY     398       Practical Problems in Atg
# 12507  2021    Fall  2021-fa    MUSC     480                   Wind Symphony
# 48057  2014    Fall  2014-fa    SPED     405     Gen Educator's Role in SPED
# 12342  2021    Fall  2021-fa     MBA     564   Applying Data Analytics Mrktg
# 16034  2020    Fall  2020-fa    BADM     567              Process Management
# 13827  2021  Spring  2021-sp    DANC     100     Intro to Contemporary Dance
# 18181  2020  Spring  2020-sp    ANSC     103       Working With Farm Animals
# 23514  2019  Spring  2019-sp      CI     473           Disciplinary Literacy
# 15146  2021  Spring  2021-sp      TE     360  Lect in Engrg Entrepreneurship
# 53715  2013  Spring  2013-sp    CHLH     380       Orientation to Internship
# 958    2023    Fall  2023-fa      CS     598    Foundations of Data Curation
# 14074  2021  Spring  2021-sp     EPS     533    Global Youth and Citizenship
# 1631   2023    Fall  2023-fa      IB     360      Evolution and Human Health
# 1780   2023    Fall  2023-fa     KIN     125   Orientation KIN & Comm Health
# 34784  2017  Spring  2017-sp     MUS     274                 Basketball Band
# 20137  2020  Summer  2020-su    EPSY     408    Learning & Hum Dev w/ EdTech
# 15507  2021  Winter  2021-wi    EPSY     408    Learning & Hum Dev w/ EdTech
# 2309   2023    Fall  2023-fa    MUSC     487                 Marching Illini
# 34780  2017  Spring  2017-sp     MUS     250                  Illini Strings
# 26453  2018    Fall  2018-fa    EDUC     101   Education Orientation Seminar
# 42590  2015    Fall  2015-fa     MUS     262               Women's Glee Club
# 8299   2022  Spring  2022-sp     BUS     301              Business in Action
# 63104  2011  Spring  2011-sp     MSE     183   Freshman Materials Laboratory
# 14370  2021  Spring  2021-sp      IS     507                Data, Stat, Info
# 4579   2023  Spring  2023-sp    MUSC     484                    Concert Band
# 35840  2016    Fall  2016-fa    BADM     420   Advanced Marketing Management
#
#       Sched Type   A+    A  A-  ...  C  C-  D+  D  D-  F  W  \
# 25230        ONL  266   18   1  ...  0   0   0  0   0  0  0
# 15304        ONL  407    9   0  ...  0   0   0  0   0  0  0
# 7310          PR    0  289   0  ...  0   0   0  0   0  0  1
# 38182        ONL  139    1   0  ...  0   0   0  0   0  0  0
# 34099        NaN   69   14   0  ...  0   0   0  0   0  0  0
# 34099             Brown, Dawn M        84     3.992024
# 47603       Philpott, Michael L       120     3.991667
# 35685              Cobb, Alan R        80     3.991625
# 40650              Cobb, Alan R        77     3.991299
# 10117          Knap, Kimberly E        72     3.990694
# 57664           Houser, Barry L       311     3.990354
# 51982  Armstrong, Christopher M        67     3.990000
# 9221            Song, Yoo-Seong        66     3.989848
# 3149           Cockrell, Adam L        66     3.989848
# 21604         Cannaday, Roger E        65     3.989692
# 7567          Clifton, Dionne J        63     3.989365
# 5050         Silvers, Michael B        94     3.989362
# 33336        Mukherjee, Ujjal K        58     3.988448
# 4578             Rudy, Hannah L        83     3.987952
# 3265         Luckman, Elizabeth        55     3.987818
# 1367          Krueger, George J        55     3.987818
# 31892      Arias Chauca, Lily C        82     3.987805
# 29017             Brown, Dawn M        81     3.987654
# 11550             Lee, Sharon S        81     3.987654
# 16672             Cope, William        81     3.987654
# 33037            Nekrasz, Frank       132     3.987348
# 12507         Peterson, Stephen        52     3.987115
# 48057         Taylor, Gregory G        51     3.986863
# 12342             Yun, Joseph T       683     3.986823
# 16034          Cockrell, Adam L        50     3.986600
# 13827         Sapozhnikov, Anna        50     3.986600
# 18181           Emmert, Jason L        74     3.986486
# 23514          Filkins, Scott R        97     3.986289
# 15146   Harbourt, Christopher M        48     3.986042
# 53715           Farner, Susan M       119     3.985966
# 958             Willis, Craig A       332     3.985964
# 14074            Herrera, Linda        47     3.985745
# 1631         Roseman, Charles C       117     3.985726
# 1780               O'Neill, Amy       140     3.985714
# 34784           Houser, Barry L       139     3.985612
# 20137             Cope, William       114     3.985439
# 15507             Cope, William       114     3.985439
# 2309            Houser, Barry L       295     3.985356
# 34780            May, Cameron L        68     3.985294
# 26453           Jo, Katherine K        68     3.985294
# 42590             Solya, Andrea        68     3.985294
# 8299                Kim, Heejin        45     3.985111
# 63104             Braun, Paul V        67     3.985075
# 14370       Besser, Stephanie A        44     3.984773
# 4579          Brinberg, Isaac H        65     3.984615
# 35840           Wolters, Mark E        65     3.984615
#
# [50 rows x 24 columns]

# %% [markdown]
# Now, using your two new DataFrames (`df_hard` and `df_easy`), find:
# - The **mean course number** of the 50 hardest courses by GPA, storing in the variable `hard_avg`
# - The **mean course number** of the 50 easiest courses by GPA, storing in the variable `easy_avg`
#
# The **course number** of a course is stored in the `Number` column of our DataFrames.

# %%
hard_avg = df_hard["Number"].mean()
hard_avg
# Out:
# np.float64(167.22)

# %%
easy_avg = df_easy["Number"].mean()
easy_avg
# Out:
# np.float64(372.96)

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASE for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell(s), make changes, and RE-RUN your code and then this cell.
import math
assert( len(df_hard) == len(df_easy) == 50 ), "Your df_hard and df_easy should be picking the 50 courses with the lowest / highest average GPA respectively. Please double check that you are selecting 50 courses."
assert( math.isclose(df_hard['Average GPA'].sum(), 80.3858156565443) ), "Your df_hard is calculated incorrectly. Make sure you are finding the 50 courses with the lowest Average GPA."
assert( math.isclose(df_easy['Average GPA'].sum(), 199.39636832538582) ), "Your df_easy is calculated incorrectly. Make sure you are finding the 50 courses with the highest Average GPA."
assert( math.isclose(hard_avg, 167.22) ), "Your calculation for the average course number of 'hard' courses is incorrect. Make sure you are finding the mean of course numbers of df_hard."
assert( math.isclose(easy_avg, 372.96) or math.isclose(easy_avg, 375.56)), "Your calculation for the average course number of 'easy' courses is incorrect. Make sure you are finding the mean of course numbers of df_easy."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: "Hardest" and "Easiest" Courses?
#
# **Q1: After solving Puzzle 1.2, your friend has the following claim:**
#
# > *"We know that the undergraduate courses are coded from 001 to 499, where a larger number (in the hundreds place) usually implies more advanced material.  Based on our results in the previous puzzles, the data shows that the junior-level and senior-level courses are clearly not the hardest courses at UIUC."*
#
# **Comment on your friend's claim below. Do you think they are correct? Explain why or why not with specific data you found.**

# %% [markdown]
# *(
# Based on the data, I agree with my friend's claim. Some of the hardest courses, as seen from the lower average GPAs, are actually lower-level courses like GS 199 and LER 120, while higher-level courses, such as IS 532, have much higher GPAs, indicating they might be easier.)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: GPA By Subject
# We've explored some of the GPA Dataset as a whole, but what if we want to investigate **differences in GPA by subject**?

# %% [markdown]
# ### Puzzle 2.1: Grouping by Subject
# To look into the different Average GPAs for each subject, we need to **group** our DataFrame.
#
# In the following cell, create a new DataFrame, `df_subject`, which will contain data from `df` grouped by `Subject` so **each letter grade column** contains the **total number of students** receiving the same grade in that `Subject`.
#
# **NUMERIC ONLY**: For the agg function in the lab, we want to aggregate only the numeric columns:
# - To do this, when you use `.agg("...")`, include the option `numeric_only=True`.
# - For example, to aggregate by `sum`, you would use: `.agg("sum", numeric_only=True)`.
# - Another example: to aggregate by `count`, you would use: `.agg("count", numeric_only=True)`.
#
# **DO I USE `count` or `sum`?**:
# - Each row in `df` represents a **course section** of a `Subject` with the **number of students** receiving grades for that course.
# - Do you want to "count" the number of rows, or "sum" the number of students receiving each grade?
# - And, don't forget to `.reset_index()`. :)

# %%
df_subject =  df.groupby("Subject").agg("sum").reset_index()
df_subject
# Out:
#     Subject     Year                                               Term  \
# 0       AAS   494134  FallFallFallFallFallFallFallFallFallFallFallFa...
# 1       ABE   334747  FallFallFallFallFallSpringSpringSpringSpringSp...
# 2      ACCY  5737609  FallFallFallFallFallFallFallFallFallFallFallFa...
# 3       ACE  2290983  FallFallFallFallFallFallFallFallFallFallFallFa...
# 4      ACES   383227  FallFallFallFallFallFallFallFallFallFallFallFa...
# ..      ...      ...                                                ...
# 169      UP   729992  FallFallFallFallFallFallFallFallFallFallFallFa...
# 170      VB     8040                             FallSpringSpringSpring
# 171     VCM   110864  FallFallFallFallFallFallSpringSpringSpringSpri...
# 172      VM   258207  FallFallFallFallFallFallFallSpringSpringSpring...
# 173    YDSH    24174  FallFallFallFallFallFallSpringSpringFallFallFa...
#
#                                               YearTerm   Number  \
# 0    2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...    30940
# 1    2023-fa2023-fa2023-fa2023-fa2023-fa2023-sp2023...    55405
# 2    2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  1079894
# 3    2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...   320492
# 4    2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...    22012
# ..                                                 ...      ...
# 169  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...   128783
# 170                       2010-fa2010-sp2010-sp2010-sp     2489
# 171  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...    34284
# 172  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...    78366
# 173  2020-fa2019-fa2017-fa2016-fa2016-fa2015-fa2014...     3340
#
#                                           Course Title  \
# 0    Intro Asian American StudiesIntro Asian Americ...
# 1    Intro Agric & Biological EngrABE Principles: M...
# 2    Fundamentals of AccountingFundamentals of Acco...
# 3    Intro to Applied MicroIntro to Applied MicroIn...
# 4    Contemporary Issues in ACESContemporary Issues...
# ..                                                 ...
# 169  Introduction to City PlanningRace, Social Just...
# 170  ToxicologyPharmacology IINutritional Aspect Fo...
# 171  Introduction to Veterinary SciVeterinary Form ...
# 172  Structure and Function IPathobiology IPathobio...
# 173  Lit Responses to the HolocaustJewish Storytell...
#
#                                             Sched Type     A+      A     A-  \
# 0    DISDISDISDISDISDISDISDISDISDISLCDLCDDISDISDISL...   1050   2829   1053
# 1    LECLECOLCLCDOLCLECONLOLCLCDLCDLCDLECLCDOLCLECL...    584   3332    912
# 2    ONLONLLECLECLECLECLCDLCDLCDLCDLCDLCDLCDLCDLCDL...  15871  36922  21865
# 3    DISDISDISDISDISDISLBDONLONLOnlLCDLECLCDLCDLECO...   8769  19270   6845
# 4    DISDISDISDISDISDISDISDISDISDISDISDISDISDISONLO...   1612   2095    393
# ..                                                 ...    ...    ...    ...
# 169  OLCONLLECLECLECLCDLCDLECLCDLECLCDLECLECLECLCDL...   1483   4977   2508
# 170                                       LECLECLECLEC      0    212      6
# 171  ONLONLONLONLONLLCDONLONLONLLECONLLCDONLONLONLL...    547   1687     35
# 172  LECLECLECLECLECLECLECLECLECLECLECLECLECLECLECL...      0   2879      8
# 173                        ONLLCDLCDLCDLCDLCDLCDLCDLCD     48    105     75
#
#      ...    C+     C    C-   D+    D   D-    F    W  \
# 0    ...   165   169    70   39   44   26  132   26
# 1    ...   148   194    50   21   52    9   74   19
# 2    ...  3912  3196  1579  439  876  294  953  363
# 3    ...  2156  3124  1032  497  882  294  993  152
# 4    ...    92    94    40   25   34   19   94   10
# ..   ...   ...   ...   ...  ...  ...  ...  ...  ...
# 169  ...   317   339   161   51  103   71  248   39
# 170  ...     0    40     0    0    2    0    0    0
# 171  ...    23   349     1    1   40    0    7    2
# 172  ...     0  4725     0    0  554    0   21   10
# 173  ...     9     7     5    1    2    1    8    2
#
#                                     Primary Instructor  Students
# 0    Zheng, ReanneZheng, ReanneChapekar, Priyanka A...      7187
# 1    Bhattarai, RabinGrift, Tony EKalita, Prasanta ...      7453
# 2    Zhang, LiGreen, Danielle HFisher, Mitchell BFi...    131902
# 3    Gundersen, Lisa CGundersen, Lisa CGundersen, L...     61842
# 4    Edmonds, Devin AEndres, A BPaulson, Nicholas D...      5098
# ..                                                 ...       ...
# 169  Braun, Lindsay MSalo, Ken EQayyum, FaizaanYeni...     13795
# 170  Dunayer, Eric KFerguson, Duncan CWallace, Rich...       387
# 171  Lowe, James FAldridge, Brian MAldridge, Brian ...      3860
# 172  Mahoney, Megan MZuckermann, Federico AMaddox, ...     16169
# 173  Harris, Rachel SMurav, Harriet LAnderson Bliss...       340
#
# [174 rows x 23 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASE for Puzzle 2.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell(s), make changes, and RE-RUN your code and then this cell.
import math
assert( len(df) == 69112  ), "Make sure to store your grouped data in `df_subject`."
assert( 'df_subject' in vars() ), "Make sure your DataFrame grouped by 'Subject' is named 'df_subject'." 
assert( len(df_subject) == 174 ), "Make sure you are grouping by 'Subject'. There are 172 Subjects in our original `df`, so the length of `df_subject` should be 172."
assert( math.isclose(df_subject.Students.mean(), 23685.287356321838) ), "Double-check that you are aggregating your df_subject correctly."
assert( "Subject" in df_subject.columns ), "Make sure to do .reset_index()."


## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Fixing our `Average GPA` Column
# Your intuition may tell you that some columns in `df_subject` look off. This is correct - given the way we've grouped the data to find **total student counts** by grade, the `Year` and `Average GPA` columns are incorrect.
#
# Let's fix this by redefining the `Average GPA` column in our `df_subject`. We've given you the code to do this since you already did it in Puzzle 1.1. You can see it's the exact same process; we're just using `df_subject` this time!
#
# **Run the cell below** to redefine the `Average GPA` column in `df_subject`.

# %%
df_subject['Average GPA'] = (df_subject['A+'] * 4 + df_subject['A'] * 4 + df_subject['A-'] * 3.67 
                    + df_subject['B+'] * 3.33 + df_subject['B'] * 3 + df_subject['B-'] * 2.67 
                    + df_subject['C+'] * 2.33 + df_subject['C'] * 2 + df_subject['C-'] * 1.67 
                    + df_subject['D+'] * 1.33 + df_subject['D'] * 1 + df_subject['D-'] * 0.67 + df_subject['F'] * 0) / df_subject['Students']
df_subject
# Out:
#     Subject     Year                                               Term  \
# 0       AAS   494134  FallFallFallFallFallFallFallFallFallFallFallFa...
# 1       ABE   334747  FallFallFallFallFallSpringSpringSpringSpringSp...
# 2      ACCY  5737609  FallFallFallFallFallFallFallFallFallFallFallFa...
# 3       ACE  2290983  FallFallFallFallFallFallFallFallFallFallFallFa...
# 4      ACES   383227  FallFallFallFallFallFallFallFallFallFallFallFa...
# ..      ...      ...                                                ...
# 169      UP   729992  FallFallFallFallFallFallFallFallFallFallFallFa...
# 170      VB     8040                             FallSpringSpringSpring
# 171     VCM   110864  FallFallFallFallFallFallSpringSpringSpringSpri...
# 172      VM   258207  FallFallFallFallFallFallFallSpringSpringSpring...
# 173    YDSH    24174  FallFallFallFallFallFallSpringSpringFallFallFa...
#
#                                               YearTerm   Number  \
# 0    2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...    30940
# 1    2023-fa2023-fa2023-fa2023-fa2023-fa2023-sp2023...    55405
# 2    2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  1079894
# 3    2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...   320492
# 4    2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...    22012
# ..                                                 ...      ...
# 169  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...   128783
# 170                       2010-fa2010-sp2010-sp2010-sp     2489
# 171  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...    34284
# 172  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...    78366
# 173  2020-fa2019-fa2017-fa2016-fa2016-fa2015-fa2014...     3340
#
#                                           Course Title  \
# 0    Intro Asian American StudiesIntro Asian Americ...
# 1    Intro Agric & Biological EngrABE Principles: M...
# 2    Fundamentals of AccountingFundamentals of Acco...
# 3    Intro to Applied MicroIntro to Applied MicroIn...
# 4    Contemporary Issues in ACESContemporary Issues...
# ..                                                 ...
# 169  Introduction to City PlanningRace, Social Just...
# 170  ToxicologyPharmacology IINutritional Aspect Fo...
# 171  Introduction to Veterinary SciVeterinary Form ...
# 172  Structure and Function IPathobiology IPathobio...
# 173  Lit Responses to the HolocaustJewish Storytell...
#
#                                             Sched Type     A+      A     A-  \
# 0    DISDISDISDISDISDISDISDISDISDISLCDLCDDISDISDISL...   1050   2829   1053
# 1    LECLECOLCLCDOLCLECONLOLCLCDLCDLCDLECLCDOLCLECL...    584   3332    912
# 2    ONLONLLECLECLECLECLCDLCDLCDLCDLCDLCDLCDLCDLCDL...  15871  36922  21865
# 3    DISDISDISDISDISDISLBDONLONLOnlLCDLECLCDLCDLECO...   8769  19270   6845
# 4    DISDISDISDISDISDISDISDISDISDISDISDISDISDISONLO...   1612   2095    393
# ..                                                 ...    ...    ...    ...
# 169  OLCONLLECLECLECLCDLCDLECLCDLECLCDLECLECLECLCDL...   1483   4977   2508
# 170                                       LECLECLECLEC      0    212      6
# 171  ONLONLONLONLONLLCDONLONLONLLECONLLCDONLONLONLL...    547   1687     35
# 172  LECLECLECLECLECLECLECLECLECLECLECLECLECLECLECL...      0   2879      8
# 173                        ONLLCDLCDLCDLCDLCDLCDLCDLCD     48    105     75
#
#      ...     C    C-   D+    D   D-    F    W  \
# 0    ...   169    70   39   44   26  132   26
# 1    ...   194    50   21   52    9   74   19
# 2    ...  3196  1579  439  876  294  953  363
# 3    ...  3124  1032  497  882  294  993  152
# 4    ...    94    40   25   34   19   94   10
# ..   ...   ...   ...  ...  ...  ...  ...  ...
# 169  ...   339   161   51  103   71  248   39
# 170  ...    40     0    0    2    0    0    0
# 171  ...   349     1    1   40    0    7    2
# 172  ...  4725     0    0  554    0   21   10
# 173  ...     7     5    1    2    1    8    2
#
#                                     Primary Instructor  Students  Average GPA
# 0    Zheng, ReanneZheng, ReanneChapekar, Priyanka A...      7187     3.517274
# 1    Bhattarai, RabinGrift, Tony EKalita, Prasanta ...      7453     3.533133
# 2    Zhang, LiGreen, Danielle HFisher, Mitchell BFi...    131902     3.435311
# 3    Gundersen, Lisa CGundersen, Lisa CGundersen, L...     61842     3.342199
# 4    Edmonds, Devin AEndres, A BPaulson, Nicholas D...      5098     3.659425
# ..                                                 ...       ...          ...
# 169  Braun, Lindsay MSalo, Ken EQayyum, FaizaanYeni...     13795     3.467809
# 170  Dunayer, Eric KFerguson, Duncan CWallace, Rich...       387     3.448760
# 171  Lowe, James FAldridge, Brian MAldridge, Brian ...      3860     3.467158
# 172  Mahoney, Megan MZuckermann, Federico AMaddox, ...     16169     2.813719
# 173  Harris, Rachel SMurav, Harriet LAnderson Bliss...       340     3.460353
#
# [174 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( len(df_subject) == 174 ), "You shouldn't be changing the length of `df_subject` when recomputing Average GPA."
assert( "Average GPA" in df_subject.columns), "Make sure your column is still named 'Average GPA'."
assert( math.isclose(df_subject['Average GPA'].mean(), 3.474516261357219) ), "Your calculation of the Average GPA by Subject is incorrect."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.3: The "Hardest" and "Easiest" Subjects?
# One way we can judge a Subject's difficulty is to consider its **Average GPA**.
#
# Using your `df_subject`'s  `Average GPA` column and the two cells below, find:
# - The **10** Subjects with the **lowest** `Average GPA`, storing in the DataFrame `hard_subjects`
# - The **10** Subjects with the **highest** `Average GPA`, storing the DataFrame `easy_subjects`

# %%
hard_subjects = df_subject.nsmallest(10,"Average GPA")
hard_subjects
# Out:
#     Subject     Year                                               Term  \
# 172      VM   258207  FallFallFallFallFallFallFallSpringSpringSpring...
# 116    MATH  5397267  FallFallFallFallFallFallFallFallFallFallFallFa...
# 163     TAM   756169  FallFallFallFallFallFallFallFallFallFallFallFa...
# 149    SAME     6039                                       FallFallFall
# 134    PHYS  2068965  FallFallFallFallFallFallFallFallFallFallFallFa...
# 108     LAT    10065                         SpringSpringFallFallSpring
# 40     CHBE   683827  FallFallFallFallFallFallFallFallFallFallFallFa...
# 41     CHEM  3864516  FallFallFallFallFallFallFallFallFallFallFallFa...
# 133    PHIL  1177027  FallFallFallFallFallFallFallFallFallFallFallFa...
# 118     MCB  4862019  FallFallFallFallFallFallFallFallFallFallFallFa...
#
#                                               YearTerm  Number  \
# 172  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...   78366
# 116  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  832939
# 163  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  116920
# 149                              2015-fa2014-fa2010-fa     437
# 134  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  296574
# 108                2016-sp2015-sp2012-fa2011-fa2011-sp     510
# 40   2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  142076
# 41   2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  374605
# 133  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  102123
# 118  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...  614869
#
#                                           Course Title  \
# 172  Structure and Function IPathobiology IPathobio...
# 116  Thinking MathematicallyTheory of ArithmeticAlg...
# 163  Mechanics in the Modern WorldIntroduction to S...
# 149  The New Middle EastThe New Middle EastIntro to...
# 134  Thinking About PhysicsThinking About PhysicsCo...
# 108  Elementary Latin IIElementary Latin IElementar...
# 40   Principles of CHEPrinciples of CHEThermodynami...
# 41   Introductory ChemistryIntroductory ChemistryIn...
# 133  Introduction to PhilosophyIntroduction to Phil...
# 118  Introductory MicrobiologyIntro Microbiology La...
#
#                                             Sched Type     A+      A     A-  \
# 172  LECLECLECLECLECLECLECLECLECLECLECLECLECLECLECL...      0   2879      8
# 116  LECLECLECLECLECLECLECLCDLCDLCDLCDLCDDISDISLCDL...  17421  41455  24395
# 163  LCDLECLECLECLECPKGPKGPKGLECLECLECLECLCDLCDLCDL...   2781   6258   4630
# 149                                          LCDLCDLEC      2     29     30
# 134  LECLECLECLECLECLECLECLECLECLECLECLECLECLECLECL...  18974  20537  13762
# 108                                    LCDLCDLCDLCDLCD     13     18     15
# 40   LCDLCDLECLECLECLECLECLECLECLECLECLECLECLECLECL...    996   4646   2512
# 41   LECLECLECLECLECLECLECLECLECLECLECLECLECONLLECD...  20644  56056  23207
# 133  LECLECONLLCDDISDISDISDISLCDLCDONLLCDLCDLCDLCDL...   1099   4656   3616
# 118  LECLABLABLABLABLABDISDISDISDISDISDISDISDISDISD...  10349  18085  14739
#
#      ...      C    C-    D+     D    D-     F     W  \
# 172  ...   4725     0     0   554     0    21    10
# 116  ...  18005  9452  5305  6649  2814  8829  1708
# 163  ...   2782  1606   981  1141   532  1278   177
# 149  ...     17     5     2     2     3     5     1
# 134  ...   9335  6985  4361  3172  3644  2021   797
# 108  ...      5     2     1     2     1     7     0
# 40   ...   2406   867   179   409    78   310    86
# 41   ...  17592  9803  4843  4997  2729  5250  1431
# 133  ...    830   483   213   286   216   949   132
# 118  ...   6117  3494  2052  1612   929  1460   436
#
#                                     Primary Instructor  Students  Average GPA
# 172  Mahoney, Megan MZuckermann, Federico AMaddox, ...     16169     2.813719
# 116  Dobbs, Theresa MDobbs, Theresa MDobbs, Theresa...    222829     2.914632
# 163  Johnson, Blake EJuarez, GabrielAdmal, Nikhil C...     37611     2.914962
# 149  Hoffman, Valerie JHoffman, Valerie JCuno, Kenn...       172     2.949884
# 134  Kuo, Eric PKuo, Eric PAnsell, Katherine AAnsel...    129880     2.968218
# 108  Foulk, John MKozak, Adam ADee, Nicholas MYona,...       111     2.990991
# 40   Yang, HongRogers, SimonMironenko, AlexanderDia...     22268     3.030871
# 41   McCarren, Elise MLeveritt, John MLeveritt, Joh...    227399     3.057198
# 133  Jensen, Erik RRowe, James FLeland, Patrick RLo...     20841     3.104231
# 118  Wilson, Brenda AAlt, Renee LAlt, Renee LAlt, R...    103948     3.108367
#
# [10 rows x 24 columns]

# %%
easy_subjects = df_subject.nlargest(10,"Average GPA")
easy_subjects
# Out:
#     Subject    Year                                               Term  \
# 125    MUSC   93024  FallFallFallFallFallFallFallFallFallFallFallFa...
# 38       CB    4022                                       SpringSpring
# 37      BUS  869655  FallFallFallFallFallFallFallFallFallFallFallFa...
# 68     ERAM   18201       FallSpringSpringFallFallFallFallSpringSpring
# 127      NE    2023                                               Fall
# 168     UKR   10070                       FallSpringSpringSpringSpring
# 44      CHP   44439  SpringFallFallFallFallFallSpringFallFallFallSp...
# 141    REES    6047                                 SpringSpringSpring
# 65     EPOL  216332  FallFallFallFallFallFallFallFallFallSpringSpri...
# 64      EOL  116933  SpringSpringWinterWinterWinterFallFallFallFall...
#
#                                               YearTerm  Number  \
# 125  2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...   21812
# 38                                      2011-sp2011-sp    1250
# 37   2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...   62697
# 68   2023-fa2023-sp2023-sp2022-fa2022-fa2022-fa2022...    5072
# 127                                            2023-fa     100
# 168                2022-fa2014-sp2013-sp2011-sp2010-sp     565
# 44   2023-sp2022-fa2022-fa2022-fa2022-fa2022-fa2022...    4575
# 141                              2018-sp2015-sp2014-sp     603
# 65   2023-fa2023-fa2023-fa2023-fa2023-fa2023-fa2023...   50302
# 64   2021-sp2021-sp2021-wi2021-wi2021-wi2020-fa2020...   31442
#
#                                           Course Title  \
# 125  University ChorusWomen's Glee ClubMen's Glee C...
# 38   Nutritional Aspect Food An MedNutritional Aspe...
# 37   Prof Responsibility & BusinessProf Responsibil...
# 68   Education LawCase Studies in Educ EthicsSurvey...
# 127                        Intro to Neural Engineering
# 168  Ukrainian CultureUkrainian CultureUkrainian Cu...
# 44   Special Topics: Uncommon ReadsHonors Uncommon ...
# 141  Introduction to Eastern EuropeIntroduction to ...
# 65   Race and Cultural DiversityRace and Cultural D...
# 64   Diversity, Leadership & PolicyDiversity in Hig...
#
#                                             Sched Type    A+      A    A-  \
# 125  PRPRPRPRPRPRPRPRPRPRPRPRPRPRPRPRPRPRPRPRPRPRPR...   250   2551    58
# 38                                              LECLEC     0    140     0
# 37   LCDLCDLCDLCDLCDLCDLCDLCDLCDLCDLCDLCDLCDLCDLCDL...  1906  10153  1507
# 68                         ONLONLONLONLONLONLONLONLONL    63    138    40
# 127                                                LCD    15      4     6
# 168                                    LCDLCDLCDLCDLCD    10    206    46
# 44       DISODODODDISDISDISODDISDISONLODODONLDISDISCNF   210    299    52
# 141                                             LECLEC    32     34     7
# 65   DISDISDISLCDONLONLONLONLONLDISDISDISONLONLONLO...   506   2821   394
# 64   ONLONLONLONLONLONLONLONLONLONLONLONLONLLCDLCDL...    93   1340   264
#
#      ...   C  C-  D+   D  D-   F   W  \
# 125  ...  14   2   0   5   0  15   4
# 38   ...   1   0   0   0   0   0   2
# 37   ...  55  17  17  21  12  42  15
# 68   ...   0   0   0   1   0   0   0
# 127  ...   0   0   0   0   0   0   0
# 168  ...   1   0   0   0   1   0   2
# 44   ...   6   1   1   0   0   6   1
# 141  ...   0   0   0   1   0   0   0
# 65   ...  23  12   2  15   1  58   9
# 64   ...   9   0   0   6   0  10   3
#
#                                     Primary Instructor  Students  Average GPA
# 125  Solya, AndreaSolya, AndreaColeman, Barrington ...      2989     3.927779
# 38              Firkins, Lawrence DForeman, Jonathan H       158     3.879747
# 37   Barbeau, AimeeBarbeau, AimeeBarbeau, AimeeBarb...     14961     3.862449
# 68   Alexander, Samuel KTaylor, Rebecca MLindgren, ...       266     3.861241
# 127                          Best-Popescu, Catherine A        28     3.845714
# 168  Ivashkiv, Roman ZWallo, Oleksandra IChumachenk...       298     3.835906
# 44   Fitzjarrald, Amy EWhite, Zuri LWhite, Zuri LJa...       622     3.835675
# 141   Pintar, Judith APintar, Judith APintar, Judith A        83     3.827590
# 65   Moton, Theopolies JMoton, Theopolies JMoton, T...      4135     3.813284
# 64   Nelson, Jennifer LDel Real Viramo, JoseMason, ...      1961     3.812254
#
# [10 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( len(hard_subjects) == len(easy_subjects) == 10 ), "Make sure you are selecting the ten hardest or easiest subjects by GPA. This means your hard_subjects and easy_subjects DataFrames should both have exactly ten rows."
assert( math.isclose(hard_subjects['Average GPA'].sum(), 29.853073007169176) ), "Your calculation for the hardest subjects by GPA is incorrect. Remember, here harder = lower Average GPA."
assert( math.isclose(easy_subjects['Average GPA'].sum(), 38.50163903261125) ), "Your calculation for the easiest subjects by GPA is incorrect. Remember, here easier = higher Average GPA."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: "Hardest" and "Easiest" Subjects?
#
# **Q2: Observe the `Subject` column of the `hard_subjects` and `easy_subjects` you've found in Puzzle 2.3 above. Do you think these are truly the "Hardest" and "Easiest" subjects at Illinois? Explain why or why not.**
#
#
# *Note: You can use http://catalog.illinois.edu/courses-of-instruction/ to find what the different `Subject` codes mean.*

# %% [markdown]
# *(I agree with this, some theoretical courses like math and psychology can be relatively difficult, and courses like music should be relatively easy)*

# %% [markdown]
# ### Puzzle 2.4: Visualizing GPA by Subject
# We've got the **Average GPA** of each `Subject` at Illinois, but what if we want to look at the **bigger picture** across all subjects? Well, data visualization comes to the rescue!
#
# Generate a **histogram** of the **Average GPA** in your `df_subject`:

# %%
df_subject["Average GPA"].plot.hist(bins=10,figsize=(8,5))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Analysis: Histogram Interpretations
#
# **Q3: Based on the histogram you generated above, what is an estimate of the Average GPA across all courses in a typical subject at Illinois is? No need for an exact answer, just estimate.**

# %% [markdown]
# *(around 3.5)*

# %% [markdown]
# ### Puzzle 2.5: Your Major!
# We've done a lot of analysis on every course and every subject, but Data Science should also be personal to you!
#
# Using your `df_subject`, isolate the row containing the `Subject` of **your Major**, storing in the variable `my_subject`:
#
# (If you're undecided, you can pick any `Subject`!)

# %%
my_subject = df_subject[df_subject["Subject"]=="ECON"]
my_subject
# Out:
#    Subject     Year                                               Term  \
# 57    ECON  7769515  WinterWinterWinterFallFallFallFallFallFallFall...
#
#                                              YearTerm  Number  \
# 57  2024-wi2024-wi2024-wi2023-fa2023-fa2023-fa2023...  966233
#
#                                          Course Title  \
# 57  Microeconomic PrinciplesMacroeconomic Principl...
#
#                                            Sched Type     A+      A     A-  \
# 57  ONLONLONLDISDISDISDISDISDISDISDISDISDISDISDISD...  22117  42231  21106
#
#     ...     C    C-    D+     D    D-     F    W  \
# 57  ...  9521  4195  2668  3268  1561  4444  905
#
#                                    Primary Instructor  Students  Average GPA
# 57  DiIanni, IsaacVazquez, Jose JSchultz, ColleenC...    170864     3.192452
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Analysis: Your Major's Average GPA
#
# **Q4: Observe the `Average GPA` column of your subject from Puzzle 2.5 above. Is it higher or lower than you expected?**

# %% [markdown]
# *(the average GPA is 3.19, which is a lttle lower than expected)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: GPA By Year
# At this point, we've investigated the GPA Dataset as a whole and grouped by `Subject`. While our GPA Dataset contains **a lot** of course data, some of the listed courses are quite old: **dating back to 2010**! To put that into perspective, a senior in college now would be no more than **8 years old** in 2010.
#
# One can question the changes to GPA **over time**. Some questions may include:
# - Has GPA gone up, because classes became "easier"?
# - Has the GPA fallen because of stricter grading policies?
# - How was GPA impacted in 2019-2020 at the brunt of COVID?
#
# You will gain some insight into the answers to questions in this section of the lab.

# %% [markdown]
# ### Puzzle 3.1: Grouping by Year
# To look into how the GPA changes by `Year`, we need to again **group** our DataFrame.
#
# In the following cell, create a new DataFrame, `df_year`, which will contain this grouped GPA data. Using `df.groupby()`, **group** our original DataFrame (`df`) by `Year` so each **letter grade column** contains the **total number of students** receiving said grade in that `Year`.
#
# Remember: You did something quite similar in Puzzle 2.1 to create `df_subject`. This might help you decide what type of **aggregation** (`.agg()`) to use when **grouping**.
# - In this puzzle, you should also use `numeric_only=True` in your `agg` function, just like in Puzzle 2.1.
# - And, don't forget to `.reset_index()`! :)

# %%
df_year = df.groupby("Year").agg("sum").reset_index()
df_year
# Out:
# 8   ...  10809  13421  5949  3339  4350  2042  6253  1131
# 9   ...  11203  13623  6117  3283  4434  2212  6914  1146
# 10  ...   8460   9944  4705  1802  2600  1153  5824   240
# 11  ...   9965  12023  5673  3309  4061  2082  9272  1332
# 12  ...   9778  11950  5516  2837  3787  1806  8083  1496
# 13  ...   8618  10202  4577  2332  3145  1423  5848  1016
# 14  ...     35     42    11     4    20     5    27     9
#
#                                    Primary Instructor  Students
# 0   Winkelmann, Marie TKwon, YaejoonKwon, YaejoonA...    271071
# 1   Kinase-Leggett, ElizabethKinase-Leggett, Eliza...    269064
# 2   Carter, Regina SCarter, Regina SArai, SayuriDa...    151677
# 3   Arai, SayuriArai, SayuriDavis, Thomas EDavis, ...    276469
# 4   Thomas, Merin AThomas, Merin APeralta, Christi...    276736
# 5   Peralta, Christine NLee, Sang SCacho, Lisa MGr...    295247
# 6   Chung, Ga YoungChung, Ga YoungLee, Jean YLee, ...    284575
# 7   Espiritu, Augusto FPaik, Angela NSharif, Lila ...    296862
# 8   Thomas, Merin ALee, Sang SKang, YoonjungThomas...    306113
# 9   Boonsripaisal, SimonUhall, Michael BKang, Yoon...    319344
# 10  Boonsripaisal, SimonKang, YoonjungWang, YuBoon...    314149
# 11  Zheng, ReanneAtienza, Paul Michael LWang, YuZh...    358816
# 12  Zheng, ReanneZheng, ReanneShin, JeongsuLee, Sa...    357042
# 13  Zheng, ReanneZheng, ReanneChapekar, Priyanka A...    342117
# 14  Hall, Steven RMcMillion, Desiree YDunne, Bryan...      1958
#
# [15 rows x 23 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASE for Puzzle 3.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( 'df_year' in vars() ), "Make sure your DataFrame grouped by Year is named 'df_year'." 
assert( len(df_year) == 15 ), "Make sure you are grouping by 'Year'. There are 15 years in our original `df`, so the length of `df_years` should be 15."
assert( math.isclose(df_year.Students.mean(), 274749.3333333333) ), "Double-check that you are aggregating your df_year correctly."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.2: Fixing our `Average GPA` Column Again
# Some columns in `df_year` are incorrectly calculated given the way we've grouped the data.
#
# Let's fix this by redefining the `Average GPA` column in our `df_year`. This is just like what we did in Puzzle 1.1 and 2.2, so we've provided the code to do this. Observe how the only thing that is different from before is the DataFrame being used.
#
# **Run the cell below** to redefine the `Average GPA` column in `df_year`.

# %%
df_year['Average GPA'] = (df_year['A+'] * 4 + df_year['A'] * 4 + df_year['A-'] * 3.67 
                    + df_year['B+'] * 3.33 + df_year['B'] * 3 + df_year['B-'] * 2.67 
                    + df_year['C+'] * 2.33 + df_year['C'] * 2 + df_year['C-'] * 1.67 
                    + df_year['D+'] * 1.33 + df_year['D'] * 1 + df_year['D-'] * 0.67 + df_year['F'] * 0) / df_year['Students']
df_year
# Out:
#     Year                                               Term  \
# 0   2010  FallFallFallFallFallFallFallFallFallFallFallFa...
# 1   2011  FallFallFallFallFallFallFallFallFallFallFallFa...
# 2   2012  FallFallFallFallFallFallFallFallFallFallFallFa...
# 3   2013  FallFallFallFallFallFallFallFallFallFallFallFa...
# 4   2014  FallFallFallFallFallFallFallFallFallFallFallFa...
# 14  ...     42    11     4    20     5    27     9
#
#                                    Primary Instructor  Students  Average GPA
# 0   Winkelmann, Marie TKwon, YaejoonKwon, YaejoonA...    271071     3.233537
# 1   Kinase-Leggett, ElizabethKinase-Leggett, Eliza...    269064     3.224523
# 2   Carter, Regina SCarter, Regina SArai, SayuriDa...    151677     3.253189
# 3   Arai, SayuriArai, SayuriDavis, Thomas EDavis, ...    276469     3.250664
# 4   Thomas, Merin AThomas, Merin APeralta, Christi...    276736     3.239539
# 5   Peralta, Christine NLee, Sang SCacho, Lisa MGr...    295247     3.266565
# 6   Chung, Ga YoungChung, Ga YoungLee, Jean YLee, ...    284575     3.275508
# 7   Espiritu, Augusto FPaik, Angela NSharif, Lila ...    296862     3.301601
# 8   Thomas, Merin ALee, Sang SKang, YoonjungThomas...    306113     3.337883
# 9   Boonsripaisal, SimonUhall, Michael BKang, Yoon...    319344     3.339275
# 10  Boonsripaisal, SimonKang, YoonjungWang, YuBoon...    314149     3.486988
# 11  Zheng, ReanneAtienza, Paul Michael LWang, YuZh...    358816     3.429146
# 12  Zheng, ReanneZheng, ReanneShin, JeongsuLee, Sa...    357042     3.447320
# 13  Zheng, ReanneZheng, ReanneChapekar, Priyanka A...    342117     3.507897
# 14  Hall, Steven RMcMillion, Desiree YDunne, Bryan...      1958     3.652891
#
# [15 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASE for Puzzle 3.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert( len(df_year) == 15 ), "You shouldn't be changing the length of `df_year` when recomputing Average GPA."
assert( "Average GPA" in df_year.columns), "Make sure your column is still named 'Average GPA'."
assert( math.isclose(df_year['Average GPA'].mean(), 3.349768485675631) ), "Your calculation of the Average GPA by Year is incorrect."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.3: Visualizing GPA over Time
# We now have the data of the `Average GPA` across the University over time in years. Using this data, we can generate yet another visualization built-in to Pandas to visualize this data: a **line plot**!
#
# You can plot a **connected line** that draws your **numeric data** from a DataFrame, `df`, using the syntax:
#
# &emsp;`df.plot.line(x='column1', y='column2')`
#
# This line of code plots the line and specifies the **column names** to be used for the **x-values** and **y-values** of the points on your line plot.
#
#
# In the cell below, using similar syntax, plot the **average GPA over time** using `df_year`.
#
# *Hint: the `Year` column should provide **x-values** and the `Average GPA` column should provide **y-values**.*

# %%
df_year.plot.line(x='Year', y='Average GPA')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ***Side Note***: If you're using **Visual Studio Code** on **dark mode**, you may not be able to see the **axes** and **axes labels** of the graph.
#
# **Only if** this is the case, please **copy and run** the following **two lines** of code in a cell:
#
# ---
# ```py
# from matplotlib import style
# style.use('dark_background')
# ```
# ---
#
# And then **re-run your plotting code** above.

# %% [markdown]
# ### Analysis: Plotted GPA over Time
#
# Note a few observations you have about the changes to `Average GPA` at Illinois over time, and answer the two following questions, making sure to use specific data and values in your answer:
# - **(5a): Is there an overall trend?**
# - **(5b): What events could have spiked increases to the Average GPA?**

# %% [markdown]
# *(5a: Yes, the Average GPA at Illinois shows a steady increase over time, especially after 2020.
# 5b: The sharp rise in GPA after 2020 could be related to the COVID-19 pandemic, which led to more lenient grading policies and flexible academic support for students.)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
